# %%
import pandas as pd

# %% [markdown]
# initial import

# %%
pd.read_csv('../Data/Speeches/cleaned_speeches.csv',sep='\t')
# Out:
#        speechID                                   speechName  paraNum  \
# 0             1         developments-in-uk-financial-markets        1
# 1             1         developments-in-uk-financial-markets        2
# 2             1         developments-in-uk-financial-markets        3
# 3             1         developments-in-uk-financial-markets        4
# 4             1         developments-in-uk-financial-markets        5
# ...         ...                                          ...      ...
# 65531       974  reflecting-diversity-choosing-the-inclusion       23
# 65532       974  reflecting-diversity-choosing-the-inclusion       24
# 65533       974  reflecting-diversity-choosing-the-inclusion       25
# 65534       974  reflecting-diversity-choosing-the-inclusion       26
# 65535       974  reflecting-diversity-choosing-the-inclusion       27
#
#                                                     para  nWords  isFootnote  \
# 0      Developments in UK financial markets Speech gi...      43       False
# 1      "The UKs new monetary framework Perhaps the si...     146       False
# 2      The framework put in place with that announcem...      33       False
# 3      "First, the target the Bank of England is to p...      79       False
# 4      "Secondly, it is then the responsibility of th...     120       False
# ...                                                  ...     ...         ...
# 65531  "Diversity must be supported by the right stru...      63       False
# 65532  "These features are integral to the MPC, FPC, ...      47       False
# 65533  More effective communication Being diverse can...      16       False
# 65534  "The past few decades have seen enormous strid...      37       False
# 65535  xv Increasingly we are asking ourselves whethe...      14       False
#
#        isGraphic  isEndMatter        date           speaker  isMPC  isFPC  \
# 0          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 1          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 2          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 3          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 4          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# ...          ...          ...         ...               ...    ...    ...
# 65531      False        False  2017-02-09       MARK CARNEY   True   True
# 65532      False        False  2017-02-09       MARK CARNEY   True   True
# 65533      False        False  2017-02-09       MARK CARNEY   True   True
# 65534      False        False  2017-02-09       MARK CARNEY   True   True
# 65535      False        False  2017-02-09       MARK CARNEY   True   True
#
#        isPRC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 65531   True
# 65532   True
# 65533   True
# 65534   True
# 65535   True
#
# [65536 rows x 13 columns]

# %% [markdown]
# descriptive stats

# %%
df= pd.read_csv('../Data/Speeches/cleaned_speeches.csv',sep='\t')

# %%
df.speechID.value_counts() # 912 speeches of varying number of paragraphs
# Out:
# speechID
# 919    442
# 273    392
# 292    375
# 970    365
# 863    331
#       ...
# 558      8
# 77       8
# 529      6
# 623      2
# 535      2
# Name: count, Length: 912, dtype: int64

# %%
df
# Out:
#        speechID                                   speechName  paraNum  \
# 0             1         developments-in-uk-financial-markets        1
# 1             1         developments-in-uk-financial-markets        2
# 2             1         developments-in-uk-financial-markets        3
# 3             1         developments-in-uk-financial-markets        4
# 4             1         developments-in-uk-financial-markets        5
# ...         ...                                          ...      ...
# 65531       974  reflecting-diversity-choosing-the-inclusion       23
# 65532       974  reflecting-diversity-choosing-the-inclusion       24
# 65533       974  reflecting-diversity-choosing-the-inclusion       25
# 65534       974  reflecting-diversity-choosing-the-inclusion       26
# 65535       974  reflecting-diversity-choosing-the-inclusion       27
#
#                                                     para  nWords  isFootnote  \
# 0      Developments in UK financial markets Speech gi...      43       False
# 1      "The UKs new monetary framework Perhaps the si...     146       False
# 2      The framework put in place with that announcem...      33       False
# 3      "First, the target the Bank of England is to p...      79       False
# 4      "Secondly, it is then the responsibility of th...     120       False
# ...                                                  ...     ...         ...
# 65531  "Diversity must be supported by the right stru...      63       False
# 65532  "These features are integral to the MPC, FPC, ...      47       False
# 65533  More effective communication Being diverse can...      16       False
# 65534  "The past few decades have seen enormous strid...      37       False
# 65535  xv Increasingly we are asking ourselves whethe...      14       False
#
#        isGraphic  isEndMatter        date           speaker  isMPC  isFPC  \
# 0          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 1          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 2          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 3          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 4          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# ...          ...          ...         ...               ...    ...    ...
# 65531      False        False  2017-02-09       MARK CARNEY   True   True
# 65532      False        False  2017-02-09       MARK CARNEY   True   True
# 65533      False        False  2017-02-09       MARK CARNEY   True   True
# 65534      False        False  2017-02-09       MARK CARNEY   True   True
# 65535      False        False  2017-02-09       MARK CARNEY   True   True
#
#        isPRC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 65531   True
# 65532   True
# 65533   True
# 65534   True
# 65535   True
#
# [65536 rows x 13 columns]

# %%
df.groupby('speechID')['nWords'].sum().astype(float).describe() # 912 speeches, average 6226 words, median 4411, min 258, max 107000
# Out:
# count       912.000000
# mean       6226.337719
# std        6675.273094
# min         258.000000
# 25%        2676.000000
# 50%        4411.500000
# 75%        7677.500000
# max      107165.000000
# Name: nWords, dtype: float64
