# %%
import pandas as pd

# %% [markdown]
# initial import

# %%
pd.read_csv('../Data/Speeches/cleaned_speeches.csv',sep='\t')
# Out:
#        speechID                                         speechName  paraNum  \
# 0             1               developments-in-uk-financial-markets        1
# 1             1               developments-in-uk-financial-markets        2
# 2             1               developments-in-uk-financial-markets        3
# 3             1               developments-in-uk-financial-markets        4
# 4             1               developments-in-uk-financial-markets        5
# ...         ...                                                ...      ...
# 88401      1495  cost-of-capital-and-uk-business-investment-sli...       17
# 88402      1503  remarks-given-by-swati-dhingra-at-econdat-2024...       10
# 88403      1520      monetary-policy-lessons-from-the-pandemic.pdf        3
# 88404      1520      monetary-policy-lessons-from-the-pandemic.pdf        5
# 88405      1520      monetary-policy-lessons-from-the-pandemic.pdf        6
#
#                                                     para  nWords  isFootnote  \
# 0      Developments in UK financial markets Speech gi...      43       False
# 1      "The UKs new monetary framework Perhaps the si...     146       False
# 2      The framework put in place with that announcem...      33       False
# 3      "First, the target the Bank of England is to p...      79       False
# 4      "Secondly, it is then the responsibility of th...     120       False
# ...                                                  ...     ...         ...
# 88401  Sales surprises and the marginal propensity to...     149       False
# 88402  Bank of England Page 12 Appendix Chart 8: Cent...      44       False
# 88403  Analytical Toolkit Fools Gold: refinements to ...      19       False
# 88404  Analytical Toolkit Fools Gold: forecast refine...      19       False
# 88405  Research design to understand mechanisms Granu...     126       False
#
#        isGraphic  isEndMatter        date           speaker  isMPC  isFPC  \
# 0          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 1          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 2          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 3          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 4          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# ...          ...          ...         ...               ...    ...    ...
# 88401      False        False  2024-05-17  CATHERINE L MANN   True  False
# 88402      False        False  2024-05-10     SWATI DHINGRA   True  False
# 88403      False        False  2024-10-14     SWATI DHINGRA   True  False
# 88404      False        False  2024-10-14     SWATI DHINGRA   True  False
# 88405      False        False  2024-10-14     SWATI DHINGRA   True  False
#
#        isPRC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 88401  False
# 88402  False
# 88403  False
# 88404  False
# 88405  False
#
# [88406 rows x 13 columns]

# %% [markdown]
# descriptive stats

# %%
df= pd.read_csv('../Data/Speeches/cleaned_speeches.csv',sep='\t')

# %%
df.speechID.value_counts() # 912 speeches of varying number of paragraphs
# Out:
# speechID
# 976     557
# 919     442
# 273     392
# 292     375
# 970     365
#        ...
# 1416      1
# 1511      1
# 1359      1
# 1503      1
# 1330      1
# Name: count, Length: 1202, dtype: int64

# %%
df
# Out:
#        speechID                                         speechName  paraNum  \
# 0             1               developments-in-uk-financial-markets        1
# 1             1               developments-in-uk-financial-markets        2
# 2             1               developments-in-uk-financial-markets        3
# 3             1               developments-in-uk-financial-markets        4
# 4             1               developments-in-uk-financial-markets        5
# ...         ...                                                ...      ...
# 88401      1495  cost-of-capital-and-uk-business-investment-sli...       17
# 88402      1503  remarks-given-by-swati-dhingra-at-econdat-2024...       10
# 88403      1520      monetary-policy-lessons-from-the-pandemic.pdf        3
# 88404      1520      monetary-policy-lessons-from-the-pandemic.pdf        5
# 88405      1520      monetary-policy-lessons-from-the-pandemic.pdf        6
#
#                                                     para  nWords  isFootnote  \
# 0      Developments in UK financial markets Speech gi...      43       False
# 1      "The UKs new monetary framework Perhaps the si...     146       False
# 2      The framework put in place with that announcem...      33       False
# 3      "First, the target the Bank of England is to p...      79       False
# 4      "Secondly, it is then the responsibility of th...     120       False
# ...                                                  ...     ...         ...
# 88401  Sales surprises and the marginal propensity to...     149       False
# 88402  Bank of England Page 12 Appendix Chart 8: Cent...      44       False
# 88403  Analytical Toolkit Fools Gold: refinements to ...      19       False
# 88404  Analytical Toolkit Fools Gold: forecast refine...      19       False
# 88405  Research design to understand mechanisms Granu...     126       False
#
#        isGraphic  isEndMatter        date           speaker  isMPC  isFPC  \
# 0          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 1          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 2          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 3          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 4          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# ...          ...          ...         ...               ...    ...    ...
# 88401      False        False  2024-05-17  CATHERINE L MANN   True  False
# 88402      False        False  2024-05-10     SWATI DHINGRA   True  False
# 88403      False        False  2024-10-14     SWATI DHINGRA   True  False
# 88404      False        False  2024-10-14     SWATI DHINGRA   True  False
# 88405      False        False  2024-10-14     SWATI DHINGRA   True  False
#
#        isPRC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 88401  False
# 88402  False
# 88403  False
# 88404  False
# 88405  False
#
# [88406 rows x 13 columns]

# %%
df.groupby('speechID')['nWords'].sum().astype(float).describe() # 1200 speeches, average 5900 words, median 4400
# Out:
# count      1202.000000
# mean       5971.695507
# std        6161.393909
# min           2.000000
# 25%        2675.250000
# 50%        4411.500000
# 75%        7323.000000
# max      107165.000000
# Name: nWords, dtype: float64

# %%
df['para']
# Out:
# 0        Developments in UK financial markets Speech gi...
# 1        "The UKs new monetary framework Perhaps the si...
# 2        The framework put in place with that announcem...
# 3        "First, the target the Bank of England is to p...
# 4        "Secondly, it is then the responsibility of th...
#                                ...
# 88401    Sales surprises and the marginal propensity to...
# 88402    Bank of England Page 12 Appendix Chart 8: Cent...
# 88403    Analytical Toolkit Fools Gold: refinements to ...
# 88404    Analytical Toolkit Fools Gold: forecast refine...
# 88405    Research design to understand mechanisms Granu...
# Name: para, Length: 88406, dtype: object

# %%
df[df['speechID'] == 5].sort_values('para')
# Out:
#      speechID                          speechName  paraNum  \
# 206         5  the-inflation-target-five-years-on       70
# 207         5  the-inflation-target-five-years-on       71
# 209         5  the-inflation-target-five-years-on       73
# 210         5  the-inflation-target-five-years-on       74
# 242         5  the-inflation-target-five-years-on      106
# ..        ...                                 ...      ...
# 201         5  the-inflation-target-five-years-on       65
# 221         5  the-inflation-target-five-years-on       85
# 223         5  the-inflation-target-five-years-on       87
# 224         5  the-inflation-target-five-years-on       88
# 238         5  the-inflation-target-five-years-on      102
#
#                                                   para  nWords  isFootnote  \
# 206  "(ii)     The Inflation Report will continue, ...     117        True
# 207  "(iii)    Appearances before the Treasury Sele...      65        True
# 209  "(iv)     The MPC is required to send an open ...     163        True
# 210  "(v)      Finally, the MPC is accountable to t...      61        True
# 242  "* Inflation is measured as the annual increas...      27       False
# ..                                                 ...     ...         ...
# 201  Transparency is desirable because it improves ...      24        True
# 221  What has been the experience of countries with...      10       False
# 223           What is the role of inflation forecasts?       7       False
# 224        Why is openness and transparency important?       6       False
# 238                                       percent 10.0       2       False
#
#      isGraphic  isEndMatter       date      speaker  isMPC  isFPC  isPRC
# 206      False        False 1997-10-29  MERVYN KING   True  False  False
# 207      False        False 1997-10-29  MERVYN KING   True  False  False
# 209      False        False 1997-10-29  MERVYN KING   True  False  False
# 210      False        False 1997-10-29  MERVYN KING   True  False  False
# 242      False        False 1997-10-29  MERVYN KING   True  False  False
# ..         ...          ...        ...          ...    ...    ...    ...
# 201      False        False 1997-10-29  MERVYN KING   True  False  False
# 221      False        False 1997-10-29  MERVYN KING   True  False  False
# 223      False        False 1997-10-29  MERVYN KING   True  False  False
# 224      False        False 1997-10-29  MERVYN KING   True  False  False
# 238      False        False 1997-10-29  MERVYN KING   True  False  False
#
# [110 rows x 13 columns]

# %%
df[['because' in i and 'inflation' in i for i in df['para']]]#['para'].values
# Out:
#        speechID                                         speechName  paraNum  \
# 176           5                 the-inflation-target-five-years-on       40
# 389           9         economic-policy-with-and-without-forecasts       22
# 439          10               edward-george-institute-of-directors       35
# 461          12                      edward-george-tuc-congression        2
# 469          12                      edward-george-tuc-congression       10
# ...         ...                                                ...      ...
# 88268      1378  monetary-policy-with-a-steady-hand-speech-by-h...       13
# 88280      1388  on-returning-inflation-back-to-target-speech-b...        4
# 88305      1395  the-state-of-financial-stability-speech-by-jon...        3
# 88312      1395  the-state-of-financial-stability-speech-by-jon...       10
# 88370      1494  climate-change-the-macroeconomy-and-monetary-p...       11
#
#                                                     para  nWords  isFootnote  \
# 176    "Many supply shocks are price level effects. F...     206        True
# 389    "We have tried to interest universities in thi...    1081       False
# 439    "Now there are those - perhaps even one or two...      88       False
# 461    "Let me start with what is perhaps your bigges...     133       False
# 469    "But, even if we agree on the objective, that ...     145       False
# ...                                                  ...     ...         ...
# 88268  Retaining flexibility is important. And given ...     327       False
# 88280  It is often said that monetary policy should l...     533       False
# 88305  Such corrections happen every day, of course. ...     428       False
# 88312  To be clear, a period of adjustment to bring t...     498       False
# 88370  Inflation Impacts what does the literature say...     109       False
#
#        isGraphic  isEndMatter       date           speaker  isMPC  isFPC  \
# 176        False        False 1997-10-29       MERVYN KING   True  False
# 389        False        False 1998-05-14         ALAN BUDD   True  False
# 439        False        False 1998-11-19      EDDIE GEORGE   True  False
# 461        False        False 1998-09-15      EDDIE GEORGE   True  False
# 469        False        False 1998-09-15      EDDIE GEORGE   True  False
# ...          ...          ...        ...               ...    ...    ...
# 88268      False        False 2022-02-09          HUW PILL   True  False
# 88280      False        False 2022-01-21  CATHERINE L MANN   True  False
# 88305      False        False 2022-03-02      JON CUNLIFFE   True   True
# 88312      False        False 2022-03-02      JON CUNLIFFE   True   True
# 88370      False        False 2024-04-25     ANDREW BAILEY   True   True
#
#        isPRC
# 176    False
# 389    False
# 439    False
# 461    False
# 469    False
# ...      ...
# 88268  False
# 88280  False
# 88305   True
# 88312   True
# 88370   True
#
# [845 rows x 13 columns]

# %%
df.date= pd.to_datetime(df.date, format='%Y-%m-%d')
df.sort_values('date')
# Out:
#        speechID                                         speechName  paraNum  \
# 69            3    edward-george-queen-elizabeth-conference-centre        1
# 92            3    edward-george-queen-elizabeth-conference-centre       24
# 91            3    edward-george-queen-elizabeth-conference-centre       23
# 90            3    edward-george-queen-elizabeth-conference-centre       22
# 89            3    edward-george-queen-elizabeth-conference-centre       21
# ...         ...                                                ...      ...
# 88389      1507  speech-slides-by-jonathan-haskel-on-uk-inflati...        2
# 88395      1511  uk-inflation-whats-done-and-whats-to-come-spee...       25
# 88404      1520      monetary-policy-lessons-from-the-pandemic.pdf        5
# 88403      1520      monetary-policy-lessons-from-the-pandemic.pdf        3
# 88405      1520      monetary-policy-lessons-from-the-pandemic.pdf        6
#
#                                                     para  nWords  isFootnote  \
# 69     "Speech by the Governor at the Queen Elizabeth...     128       False
# 92     "And I conclude, thirdly, that there remains s...      34       False
# 91     "I conclude, secondly, that the markets see cu...      30       False
# 90     "I conclude, first, that markets at present ar...      79       False
# 89     "What can we conclude from all this, Mr Chairm...      22       False
# ...                                                  ...     ...         ...
# 88389  1. Some questions about inflation, uncertainty...      28       False
# 88395  Bank of England Page 29 Price inflation CPI pu...     844       False
# 88404  Analytical Toolkit Fools Gold: forecast refine...      19       False
# 88403  Analytical Toolkit Fools Gold: refinements to ...      19       False
# 88405  Research design to understand mechanisms Granu...     126       False
#
#        isGraphic  isEndMatter       date          speaker  isMPC  isFPC  isPRC
# 69         False        False 1997-02-25     EDDIE GEORGE  False  False  False
# 92         False        False 1997-02-25     EDDIE GEORGE  False  False  False
# 91         False        False 1997-02-25     EDDIE GEORGE  False  False  False
# 90         False        False 1997-02-25     EDDIE GEORGE  False  False  False
# 89         False        False 1997-02-25     EDDIE GEORGE  False  False  False
# ...          ...          ...        ...              ...    ...    ...    ...
# 88389      False        False 2024-07-08  JONATHAN HASKEL   True  False  False
# 88395      False        False 2024-07-08  JONATHAN HASKEL   True  False  False
# 88404      False        False 2024-10-14    SWATI DHINGRA   True  False  False
# 88403      False        False 2024-10-14    SWATI DHINGRA   True  False  False
# 88405      False        False 2024-10-14    SWATI DHINGRA   True  False  False
#
# [88406 rows x 13 columns]

# %%
df = pd.read_csv(r"C:\Users\339306\Downloads\CBS_dataset_v1.0.csv",nrows = 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\339306\Downloads\CBS_dataset_v1.0.csv",nrows = 100)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\339306\Downloads\CBS_dataset_v1.0.csv")

# %%
df['Language'].value_counts()
# Out:
# Language
# English             30140
# Spanish               834
# German                698
# Italian               612
# Portuguese            537
# French                361
# Albanian              333
# Finnish               312
# Swedish               231
# Dutch                 222
# Thai                  201
# Greek                  84
# Icelandic              82
# Norwegian              81
# Chinese                78
# Turkish                74
# Indonesian             67
# Bulgarian              63
# Korean                 59
# Croatian               57
# Macedonian             56
# Hebrew                 44
# Danish                 42
# Russian                35
# Lithuanian             34
# Slovak                 30
# Arabic                 22
# Czech                  16
# Kazakh                 14
# Armenian               14
# Slovenian              13
# Creole                 12
# Polish                  9
# Khmer                   6
# French and Dutch        5
# Bosnian                 3
# Nepali                  2
# Filipino                2
# Samoan                  2
# Name: count, dtype: int64

# %%
df[df['Language']=='English']['CentralBank'].value_counts()
# Out:
# CentralBank
# Board of Governors of the Federal Reserve    2658
# European Central Bank                        2522
# Bank of England                              1354
# Reserve Bank of India                        1071
# Central Bank of the Philippines               990
#                                              ...
# Central Bank of Bolivia                         1
# Central Bank of Jordan                          1
# Bank of the Republic of Burundi                 1
# Central Bank of Ecuador                         1
# Central Bank of Uruguay                         1
# Name: count, Length: 132, dtype: int64

# %%
pd.to_datetime(df['Date']).min(),pd.to_datetime(df['Date']).max()
# Out:
# (Timestamp('1986-01-06 00:00:00'), Timestamp('2023-12-29 00:00:00'))

# %%
print(df[df['Language']=='English'][['text','Date']].iloc[-1])
# Out:
# text    Speeches\n\nBeyond Short-Term Interests\n\nJac...
# Date                                           2003-11-21
# Name: 35486, dtype: object

# %%
import os

# %%
os.listdir("../Data/Speeches/")
# Out:
# ['cleaned_speeches.csv', 'speechContent.txt', 'speechMetadata.csv']

# %%
for i in df[df['Language']=='English']['CentralBank'].value_counts().iloc[0:50].reset_index().iterrows():
    print(i)
    #print(df[df['Language']=='English'][df['CentralBank']==i]['text'].values[0][:100])
    print('\n')
# Out:
# (0, CentralBank    Board of Governors of the Federal Reserve
# count                                               2658
# Name: 0, dtype: object)
#
#
# (1, CentralBank    European Central Bank
# count                           2522
# Name: 1, dtype: object)
#
#
# (2, CentralBank    Bank of England
# count                     1354
# Name: 2, dtype: object)
#
#
# (3, CentralBank    Reserve Bank of India
# count                           1071
# Name: 3, dtype: object)
#
#
# (4, CentralBank    Central Bank of the Philippines
# count                                      990
# Name: 4, dtype: object)
#
#
# (5, CentralBank    Monetary Authority of Singapore
# count                                      914
# Name: 5, dtype: object)
#
#
# (6, CentralBank    Deutsche Bundesbank
# count                          903
# Name: 6, dtype: object)
#
#
# (7, CentralBank    Bank of Japan
# count                    826
# Name: 7, dtype: object)
#
#
# (8, CentralBank    Central Bank of Ireland
# count                              728
# Name: 8, dtype: object)
#
#
# (9, CentralBank    Central Bank of Malaysia
# count                               699
# Name: 9, dtype: object)
#
#
# (10, CentralBank    Reserve Bank of Australia
# count                                641
# Name: 10, dtype: object)
#
#
# (11, CentralBank    Bank of Canada
# count                     640
# Name: 11, dtype: object)
#
#
# (12, CentralBank    Federal Reserve Bank of New York
# count                                       614
# Name: 12, dtype: object)
#
#
# (13, CentralBank    Sveriges Riksbank
# count                        532
# Name: 13, dtype: object)
#
#
# (14, CentralBank    Federal Reserve Bank of Atlanta
# count                                      527
# Name: 14, dtype: object)
#
#
# (15, CentralBank    Swiss National Bank
# count                          493
# Name: 15, dtype: object)
#
#
# (16, CentralBank    South African Reserve Bank
# count                                 453
# Name: 16, dtype: object)
#
#
# (17, CentralBank    Federal Reserve Bank of San Francisco
# count                                            449
# Name: 17, dtype: object)
#
#
# (18, CentralBank    Bank of France
# count                     435
# Name: 18, dtype: object)
#
#
# (19, CentralBank    Hong Kong Monetary Authority
# count                                   434
# Name: 19, dtype: object)
#
#
# (20, CentralBank    Bank of Italy
# count                    428
# Name: 20, dtype: object)
#
#
# (21, CentralBank    Bank of Spain
# count                    419
# Name: 21, dtype: object)
#
#
# (22, CentralBank    Federal Reserve Bank of Chicago
# count                                      418
# Name: 22, dtype: object)
#
#
# (23, CentralBank    Bank of Uganda
# count                     365
# Name: 23, dtype: object)
#
#
# (24, CentralBank    Federal Reserve Bank of Cleveland
# count                                        353
# Name: 24, dtype: object)
#
#
# (25, CentralBank    Norges Bank
# count                  308
# Name: 25, dtype: object)
#
#
# (26, CentralBank    Bank of Albania
# count                      299
# Name: 26, dtype: object)
#
#
# (27, CentralBank    Bank of Thailand
# count                       291
# Name: 27, dtype: object)
#
#
# (28, CentralBank    De Nederlandsche Bank
# count                            283
# Name: 28, dtype: object)
#
#
# (29, CentralBank    Federal Reserve Bank of Philadelphia
# count                                           282
# Name: 29, dtype: object)
#
#
# (30, CentralBank    Bank of Finland
# count                      282
# Name: 30, dtype: object)
#
#
# (31, CentralBank    Central Bank of Kenya
# count                            275
# Name: 31, dtype: object)
#
#
# (32, CentralBank    State Bank of Pakistan
# count                             267
# Name: 32, dtype: object)
#
#
# (33, CentralBank    Federal Reserve Bank of Richmond
# count                                       266
# Name: 33, dtype: object)
#
#
# (34, CentralBank    Central Bank of Hungary
# count                              263
# Name: 34, dtype: object)
#
#
# (35, CentralBank    Bangladesh Bank
# count                      254
# Name: 35, dtype: object)
#
#
# (36, CentralBank    Federal Reserve Bank of St Louis
# count                                       252
# Name: 36, dtype: object)
#
#
# (37, CentralBank    Reserve Bank of New Zealand
# count                                  252
# Name: 37, dtype: object)
#
#
# (38, CentralBank    Federal Reserve Bank of Boston
# count                                     231
# Name: 38, dtype: object)
#
#
# (39, CentralBank    Federal Reserve Bank of Dallas
# count                                     230
# Name: 39, dtype: object)
#
#
# (40, CentralBank    Bank of Mauritius
# count                        228
# Name: 40, dtype: object)
#
#
# (41, CentralBank    People's Bank of China
# count                             221
# Name: 41, dtype: object)
#
#
# (42, CentralBank    Bulgarian National Bank
# count                              201
# Name: 42, dtype: object)
#
#
# (43, CentralBank    Bank of Greece
# count                     198
# Name: 43, dtype: object)
#
#
# (44, CentralBank    Central Bank of the Republic of Turkey
# count                                             197
# Name: 44, dtype: object)
#
#
# (45, CentralBank    Bank of Zambia
# count                     196
# Name: 45, dtype: object)
#
#
# (46, CentralBank    Bank of Portugal
# count                       185
# Name: 46, dtype: object)
#
#
# (47, CentralBank    National Bank of Serbia
# count                              173
# Name: 47, dtype: object)
#
#
# (48, CentralBank    Federal Reserve Bank of Kansas City
# count                                          170
# Name: 48, dtype: object)
#
#
# (49, CentralBank    Reserve Bank of Fiji
# count                           169
# Name: 49, dtype: object)

# %%
df.iloc[-1]
# Out:
# URL              https://fraser.stlouisfed.org/title/statements...
# PDF              https://fraser.stlouisfed.org/files/docs/histo...
# Title            Beyond Short-Term Interests : Atlanta Regional...
# Subtitle                                                       NaN
# Date                                                    2003-11-21
# Authorname                                              Jack Guynn
# Role                                                      Governor
# Gender                                                        Male
# CentralBank                        Federal Reserve Bank of Atlanta
# Country                                                        USA
# text             Speeches\n\nBeyond Short-Term Interests\n\nJac...
# text_original                                                  NaN
# Filename                        beyond-short-term-interests-521702
# Language                                                   English
# Source                                                    Archives
# Name: 35486, dtype: object

# %%
for i in df[(df['Language']=='English') & (df['CentralBank']=='Bank of England')].sort_values('Date').sort_values('Date').iloc[-1]['text'].split('.'):
    print(i)
# Out:
# Bank of England Page 1 Monetary policy as engineering? - soeech by Sarah Breeden Given at the Institute of International Finance's Talking Policy Series 19 December 2023 Bank of England Page 2 Speech 1
#  This is my first speech as a Deputy Governor and member of the Monetary Policy Committee (MPC) at the Bank of England
#  I am going to use the speech to describe my approach to monetary policy and how I am applying it to the situation the MPC currently finds itself in
#  I can think of few better places to do so than a 'Talking Policy' seminar, and I am very grateful to have been invited along to speak to you all today
#  2
#  I will focus on a few important questions
#  Where is the economy now? How did we get here? What could happen next? What does that mean for my approach to monetary policymaking? And finally, why is that approach the right thing for the economy? Where is the economy now? 3
#  Monetary policymakers like to talk about uncertainty
#  But it is fair to say that working out what the state of the UK economy is and where it's heading is especially uncertain at the moment
#  There are measurement issues?, volatility in the data and exceptionally large data revisions
# * The bottom line is that it is more difficult to extract a clear signal from the noise
# * That said, I will start by briefly painting a picture of what I think is happening in the economy in general terms
#  4
#  First, economic activity has been practically flat since the end of 2022
#  That is of course stronger than the MPC and other forecasters expected this time last year, in part because of the adjustment to energy supply headwinds and the steep fall in energy prices since then
#  But in historical terms it is very weak
#  GDP has grown by about 0
# 5% over the past year, which compares to average annual growth of 1
# 5% since the Global Financial Crisis - itself a period of low growth by historical standards
#  5
#  Second, the labour market is loosening but it remains tight
#  The survey-based employment indicators point to a tentative slowdown in hiring
#  The level of vacancies has fallen from a peak of 1
# 3 million in the middle of last year to just under a million in the latest data
#  But that is still more than 100,000 above its pre-Covid level, which itself was elevated by historical standards
#  And importantly, whilst wage growth has finally begun to fall it is still greater than 7% on most measures, which given the current weakness in productivity growth in the UK is several percentage points higher than a level that, if sustained, would be consistent with the inflation target
#  6
#  Third, inflation has been falling over the past year but it remains far too high
#  It peaked at 11
# 1% in October 2022 and was 4
# 6% in the October data
#  A naive calculation would imply that we have done more than two thirds of the work to get inflation back to target
#  1 Alan Greenspan called uncertainty the 'defining characteristic' of the monetary policy landscape
#  2 For example, the ONS is dealing with issues caused by a decline in the response rate to the Labour Force Survey, which is the MPC's most important source of information on the unemployment rate
#  3 For example, the revision to the final UK PMI for September 2023 was the 3rd largest since records began
#  4 My colleague Ben Broadbent yesterday set out some challenges around understanding the state of the UK economy at the moment, and how the MPC's usual policymaking approach focuses on a range of indicators
#  5 In the MPC's November 2022 forecast GDP was expected to fall by 2% over the year to Q4 2023
#  6 Bank staff estimate that the rate of trend productivity growth in the economy as a whole is around 1%
#  In combination with inflation of 2%, that implies nominal wage growth of 3% on average, all else equal
#  Bank of England Page 3 But much of the fall in inflation so far owes to base effects: the mechanical counterpart of the unprecedented increase in the level of energy prices that came to an end just over a year ago, with a much smaller contribution so far from the significant monetary policy tightening
# ' Taken at face value, the MPC's November forecast implies that inflation will not return to the 2% target for another two years, so we expect to have a way to go
#  How did we get here? 7
#  It is worth stepping back to review how we got here
#  I think a few points of context are particularly important to bear in mind
#  First, the UK economy has been hit by a series of unprecedented shocks
#  The UK's departure from the European Union coincided with a once-in-a-hundred year pandemic during which much of the UK and global economies were shut down
#  The process of reopening those economies met with supply chain frictions that pushed up materially on the prices of globally traded goods
#  Then in 2022 Russia staged an unprovoked and unjustified invasion of Ukraine, starting the biggest war in Europe for 80 years, and pushing up European energy prices by many multiples as a consequence
#  Most of these shocks - but of course not all of them - have affected other advanced economies too
#  All have contributed to volatility in economic activity and inflation
#  Second, high inflation since 2021, which was initially caused by imported goods and energy prices, has led to the emergence of second-round effects on wages and prices in the UK
#  This process has been supported by exceptional tightness in the labour market, and has been stubborn even in the face of the shocks I just described
#  These second-round effects have contributed to persistence in inflation in the UK and, albeit to a lesser extent, in other advanced economies
# ' 10
#  Third, demand has been resilient and supply has been very weak
#  The tight labour 11 market and elevated inflation - especially for goods and services that tend to have a larger domestic cost component - point to a UK economy that is operating at or above capacity
#  But the data suggest that economic activity has been flat
#  That implies that supply has been very weak, which is a natural consequence of some of the shocks I mentioned earlier
#
#  These have combined to deliver a series of significant forecast surprises in the UK and other advanced economies
#  Focusing on the UK, until very recently inflation had been much higher over the past couple of years than we had expected
#  And as I said before, economic activity has been more resilient than we expected
#  Chart 1 shows that the scale of these surprises - based on one-year-ahead forecasts - has been larger than at any point since the Global Financial Crisis
# 1'' Some of the surprises, for example in 7 As I said in my parliamentary appointment questionnaire, inflation could have been three to five percentage points higher at its peak had the MPC not increased Bank Rate at all
#  8 The Governor Andrew Bailey has described this as 'a time of macroeconomic upheaval'
#  See a recent speech by my colleague Jonathan Haskel for more on this
#  10 When inflation and wage growth are high, they also tend to be more volatile, which adds to issues around extracting a signal from the data
#  I return to this idea later in the speech
#  11 The MPC's forecasts condition on market expectations for Bank Rate and energy prices, among other things
#  Part of the increase in forecast surprises has been driven by volatility in those variables
#  Bank of England Page 4 late 2022, looked like textbook supply shocks, with stronger inflation coming at the same time as weaker GDP
#  More recently GDP has been much stronger than our forecasts a year ago, with inflation weaker than expected, suggesting some unwind of prior supply shocks
#  Chart 1: Over the past few years the MPC have had to deal with larger forecast surprises than at any point since the Global Financial Crisis @) One-year-ahead forecast surprises (data minus forecast, pp) 7 6 e e 5 Late 2022 ---" e 4 e) e 3 ee e a 25 @ 2008-2020 eed 1 ry e@ Since 2020 fo 05 1 -2 -3 -25 -20 15 -10 5 0 5 GDP growth Source: Bank of England, ONS (a) The chart shows the difference between quarterly data outturns for year on year growth in GDP and CPI inflation and the MPC's modal forecast for those variables made one year earlier
#  The forecasts condition on market expectations for Bank Rate, energy prices and other factors at the time the forecasts were made
#  12
# In general these surprises tend to have been serially correlated - particularly for inflation - meaning that positive surprises tend to have been followed by further positive surprises
# '? These large inflation surprises have been common across advanced economies, including the US and the euro area
#  13
# To state the obvious, this context has made monetary policymaking difficult
#  I have learned two important lessons
#  First inflation and wage growth have been stronger than our models would have predicted, suggesting greater second-round effects than I would have expected before this inflationary episode
#  Second, there is more uncertainty than usual about the speed and scale of the monetary transmission mechanism, especially given the unprecedented tightening we have seen
#  14
# What I take from this is that we are in a state of the world where monetary policymaking is best considered as engineering rather than science
#  The shocks and data surprises are too large for us to have any hope of understanding the detail of what is happening in a complex system and fine tuning economic outcomes through our 12 The trailing two year correlation between the one-year-ahead quarter-on-quarter inflation surprise and its own lag increased to around 0
# 7-0
# 8 over the past year and a half
#  The BIS have also shown that one-year- ahead inflation surprises have been positively correlated with two-year-ahead surprises historically
#  Bank of England Page 5 models
#  Instead - like engineers - we should pay attention to real world outcomes and adjust accordingly
# ? 15
#  That means we have had to remain open-minded to make sure that we continually learn how the economy is responding to these shocks
#  We have had to remain humble about how well economic models perform when movements in important variables are 'out of sample' - in other words historically unprecedented
#  We have had to place more emphasis than usual on what we know has happened, or is happening, in the economy and acknowledge that future projections are more uncertain than usual
# '* And given the uncertainty around the things we are simply unable to observe but that matter a lot now for policy - most obviously trends in supply - we have had to rely more on extracting signals from so-called 'late cycle' indicators, such as inflation and wage growth, rather than indicators of economic activity
# ' 16
# One approach that I think helpful is to think through a range of possible scenarios for the UK economy, where those scenarios reflect how real world outcomes have differed from our expectations - our lessons learned from engineering, if you like
#  Why is scenario analysis helpful? 17
# Scenarios enable us to explore policy relevant potential outcomes rather than focusing only on the thing that is most likely to happen
#  It's an approach we often use in financial stability - including on the Financial Policy Committee - where policymakers are inherently interested in tail outcomes rather than the central case, which naturally requires analysis of scenarios
#  But I have also found scenario analysis to be a useful guide for monetary policymaking during a time of major shocks
#  And I hope through explaining the role that scenario analysis has had in my own thinking on monetary policy I can make the case for the MPC to do more of it in the future
#  18
# So what are the relevant scenarios for the UK economy at the moment? In my view the potential distribution of inflation outcomes is wider than it used to be - by which I mean that the probabilities of meaningfully above and meaningfully below target inflation are much higher than we might usually expect - and I have less confidence than I used to in any given inflation profile coming to pass
#  19
#  Similarly, whilst the MPC's latest forecast implies that inflation is most likely to be 1
# 9% in two years - and the mean, or expected value, is 2
# 2% - there is a material probability that it could be much higher or much lower
# * 13 I would like to thank Tim Jackson (an engineer and my husband) for inspiring the theme of this speech, although I have since discovered that Professor Gregory Mankiw also used the analogy in the 2000s here
#  14 See, for example, the February 2023 MPC minutes, which mentioned "additional weight being put on recent strength in the labour market and inflation data, and relatively less on the medium-term projections'
#  15 See a recent speech by my colleague Ben Broadbent, which covers this theme
#  He also covered the theme in his speech yesterday
#  16 See a recent speech by my former colleague Silvana Tenreyro, which contains more discussion of the fan charts and of forecasting in the face of major economic shocks
#  Bank of England Page 6 What are the relevant scenarios? 20
# 1 am going to set out two scenarios in this speech, reflecting two states of the world that would have very different implications for inflation and for monetary policy
#  These scenarios have informed my approach to setting policy, and in particular how I've approached setting policy in an environment where there are these competing risks
# '" 21
# Chart 2 shows in (I should emphasise) illustrative terms what these scenarios could look like
#  In one scenario - the 'low inflation scenario' - there is a negative shock and demand weakens much more quickly than expected as the MPC's previous tightening in monetary policy takes hold
#  Ultimately, and assuming for now no change in the path of Bank Rate, inflation would fall well below target
#  In the other scenario - the 'high inflation scenario' - inflation remains stubbornly persistent as a result of continued and strengthened second-round effects
#  ' Chart 2: Illustrative high and low inflation scenarios for the UK economy, alongside the MPC's most likely forecast in November 2023 @) Inflation in scenarios (percent) 12 November 2023 (market rates) -- High inflation: second-round effects Low inflation: weaker demand 2021 2022 2023 2024 2025 2026 Source: Bank of England (a) The chart shows the MPC's November 2023 modal forecast for CPI inflation, conditioned on market expectations for Bank Rate at that time
#  The high inflation scenario could be thought of as one in which, for instance, the labour market remains tight and second-round effects are very significant
#  The low inflation scenario could instead be thought of as one in which the economy is hit by negative demand shocks that reduce demand materially relative to the November forecast
#  The scenarios should be interpreted as illustrative only
#  22
# This of course begs the question of how policy should respond in these states of the world
#  That is impossible to describe in the abstract
#  But one possible window into it is 17 The MPC's November 2023 minutes touched on a similar theme, saying that the 'decision whether to increase or to maintain Bank Rate at this meeting was again finely balanced between the risks of not tightening policy enough when underlying inflationary pressures could prove more persistent, and the risks of tightening policy too much given the impact of policy that was still to come through'
#  18 My colleague Huw Pill called this 'intrinsic inflation persistence' in a recent speech
#  Bank of England Page 7 the so-called 'optimal policy projection'
# 1 This is just one particular, simple, representation of how interest rates might have to respond to the scenarios, and in this version it assumes that the policymaker is focused only on returning inflation to target
#  It is clearly just a straw person
#  But it is nevertheless a useful yardstick to size quite how material these scenarios could be for Bank Rate
#  Chart 3: Estimated optimal monetary policy response to high and low inflation scenarios for the UK economy, assuming the policymaker places no weight on output stabilisation, for illustrative purposes ) Bank Rate in scenarios (percent) 10 eee History 9 -- High inflation: second-round effects 8 Low inflation: weaker demand 7 6 5 4 3 2 1 0 2021 2022 2023 2024 2025 2026 Source: Bank of England (a) The chart shows the estimated 'optimal policy projection' associated with the high and low inflation scenarios
#  See this annex for further details
#  In these scenarios - which are designed to focus on potential inflation outcomes, rather than any trade-offs with output stabilisation - we assume a lambda parameter of zero, and some preference for interest rate smoothing
#  The high inflation scenario assumes that the labour market remains tight and second-round effects are very significant
#  The low inflation scenario assumes that the economy is hit by negative demand shocks that reduce demand materially relative to the November forecast
#  The scenarios should be interpreted as illustrative only
#  23
# Chart 3 shows how in this thought experiment the scenarios would, unsurprisingly, have very different implications for Bank Rate
#  In the low inflation scenario, Bank Rate would fall from the end of this year onwards, to prevent inflation from falling materially below target
#  In the high inflation scenario, Bank Rate would rise throughout 2024 to bring inflation down, before broadly stabilising somewhere well above 6%
# ? 24
# Let me underline, these scenarios are meant to be illustrative only and not a precise read on what I think monetary policy would have to do
#  The projection has a number of 19 See the annex to this previous speech by my colleague Ben Broadbent for more on the details of the 'optimal policy projection'
#  In these particular illustrative scenarios - which are designed to focus on potential inflation outcomes, rather than the potential trade-off with output stabilisation - we assume a lambda parameter of zero
#  20 In both cases, the optimal policy projection would of course deliver a path for inflation that is closer to target than the underlying inflation scenarios
#  Bank of England Page 8 unrealistic simplifying assumptions, including that everyone knows and understands the path for the economy
#  It also depends on a precise estimate of the monetary transmission mechanism, which is very uncertain as I noted above
#  But it does show the potential for very different paths for Bank Rate depending on which scenario we find ourselves in
#  Monetary policy from here 25
# How might such scenario analysis be useful in considering policy? It is impossible to place precise probabilities on the likelihood of either of these scenarios, although I think the MPC's modal forecast is more likely to occur than either of them
#  Nevertheless understanding how a policymaker would respond in either scenario is useful to anyone who is interested in understanding the outlook for policy from here
#  The approach also underlines how, when there are significant risks, policy may need to be nimble as we learn more about which state of the world we might be in
#  (Indeed, in much the same way, my colleague Ben Broadbent talked yesterday about trading off timeliness against forming a better understanding of what's going on in the economy
# *') That process of working out what's going on should rely on the accumulation of evidence rather than any individual data point
#  Finally, in my view, the high inflation scenario would be clearly the more costly scenario - and it is therefore the most important scenario to lean against when we are setting monetary policy
#  26
# Where does that leave monetary policy over the next few months? The economy is moving in the right direction to return inflation to the 2% target, but our job isn't done
#  The question I am focused on is whether there is evidence of more persistent inflationary pressures which means we may need to tighten further
#  Regardless, monetary policy still needs to be restrictive for an extended period of time to keep pushing down on inflation and to return it sustainably to target
#  27
# Given the uncertainty, I will continue to use a range of evidence - incorporating soft data, such as surveys, as well as real world conversations with businesses and others - to inform my view of where the economy is heading
#  As part of that, I will be focused on signs that the loosening in the labour market is accelerating, and wage growth is falling more sharply than expected, for example through timely surveys and real world reports from the Bank's network of Agents
#  28
# At our December meeting, my reading of the evidence available at the time was that holding Bank Rate constant at 5
# 25% would be the best approach to managing these risks
#  What happens when inflation is high? 29
# 1 said earlier that I considered the high inflation scenario clearly the more costly - and therefore the most important to lean against when setting monetary policy
#  High inflation for an even more extended period would be damaging for households, 21 See here for Ben Broadbent's speech
#  Bank of England Page 9 businesses and the economy, making us all poorer
# ?? I'll finish the speech by spending some time explaining why that is
#  I'll start by noting a few important features of high inflation scenarios
# " 30
# First, high inflation tends to come with volatility in prices
#  By that I mean that when the general rate of price increases is high, that rate tends to jump around a lot
#  As the rate of inflation doubles, the volatility of inflation tends roughly to double too
# "4
#  Second, high inflation tends to come with more frequent price changes
#  It has been widely documented that many businesses only adjust their prices at pre-defined regular intervals
#  Few businesses change prices every day
#  But the frequency of price changes tends to go up when inflation is high
#  UK businesses reported much less frequent price changes in 2019, when inflation was relatively low, than in 2022 when inflation had risen materially
#  32
#  Third, high inflation tends to come with larger changes in relative prices
#  The data shows that the rates of inflation for different products disperse when inflation is high
#  That relationship is evident for simple comparisons of goods and services inflation - goods prices tend to rise much faster than services prices when inflation is high - and also across the full CPI basket
#  33
#  Fourth, high inflation tends to come with people paying more attention to inflation
# " Former Chair of the Federal Reserve Alan Greenspan defined price stability as when 'households and businesses need not factor expectations of changes in the average level of prices into their decisions
#  Current Fed Chair Jerome Powell made a similar point in 2022
# 27 34
#  Fifth, high inflation can make people lose trust in institutions
#  The central bank and other economic policy institutions need to establish and maintain trust in their commitment to economic stability
#  If people's inflation expectations are low and stable this directly contributes to price stability
#  If inflation is high for too long, people can begin to lose that trust, and that risks a self-fulfilling expectation that inflation will accelerate
# 78 3 Why is high inflation so damaging? 35
#  These features of high inflation scenarios pose a number of problems for the economy
#  36
# High inflation distorts production decisions
#  Volatility and relative price changes make it difficult for businesses to extract signals from the prices that they see in the market
#  22 As discussed in a speech by my colleague Ben Broadbent, there is nothing that monetary policy could have done to offset the negative real income impact of the terms of trade shock we have experienced
#  23 See the annex for some empirical evidence supporting these points
#  Former Governor of the Bank Mervyn King talked about similar themes in a speech ten years on from the introduction of inflation targeting
#  24 There is some evidence that volatility picks up when inflation is very low or negative, which would lend support to arguments that suggest low, but not too low, inflation minimises undesirable volatility in inflation
#  25 In the limit, fully flexible prices would have implications for the transmission of monetary policy
#  26 The theory of 'rational inattention' would imply that this leaves them less bandwidth to think about other things, making them worse off
#  It also risks an extremely damaging scenario, where people expect price inflation to accelerate out of control, and this ends up de-anchoring inflation expectations and is self-fulfilling
#  27 At the Jackson Hole summit in 2022 Chair Jerome Powell said 'When inflation is persistently high, households and businesses must pay close attention and incorporate inflation into their economic decisions
#  When inflation is low and stable, they are freer to focus their attention elsewhere
# ' 28 See van der Cruijsen et al (2023) for an extensive discussion of the importance of trust in central banks
#  Bank of England Page 10 They can mistake movements in the overall price level for movements in the demand for their products
#  This can lead them to produce the wrong quantity of a product, creating a misallocation of resources in the economy and unnecessary volatility
#  37
# High inflation also reduces investment and hiring, which in turn reduces the productive capacity of the economy
#  It makes it difficult for businesses to plan ahead, effectively increasing the cost of expansion
#  Plus the uncertainty that comes with high inflation increases the incentive to 'wait and see' if volatility dies down before making expansion decisions
#  This reduces the overall level of investment and hiring, and therefore output
#  38
#  It distorts household decisions for similar reasons
#  It adds uncertainty and noise to decisions around liquidity management, saving and borrowing
#  This reduces the ability of consumers to smooth their consumption over time
#  39
# High inflation increases the risk of unexpected redistributions of income and wealth
#  As inflation rises, households and businesses will be in conflict as they attempt to defend their real incomes
# 2 Unexpected increases in prices erode the real value of savings - because nominal interest rates tend not to keep up with inflation, and cash pays no interest
#  Unexpectedly high inflation also erodes the real value of debt that isn't index- linked, including most mortgages
#  So it leads to redistribution from creditors to debtors, and from current to future creditors
# * 40
# And finally, households with the lowest incomes tend to be hit the hardest by high inflation
#  The data shows that since the end of 2021 the inflation rates faced by the lowest decile of the household income distribution have been much higher than those faced by the highest decile
# *' That is because they tend to spend more of their money on the products that have increased in price by the most, such as food, heating and electricity
#  Lower income households have also had a bigger real income hit than richer households, leading to a negative impact on their living standards
# *? These households often find it most difficult to deal with the consequences of these impacts
#
#  The problems of a high inflation scenario underline the importance of the MPC avoiding high inflation scenarios and returning inflation sustainably to its 2% target
#  4 What about financial stability? 42
# Much of my career to date has been in the financial stability policy world
#  I have said before that monetary and financial stability are complementary - or two sides of the same coin
# *? Maintaining low and stable inflation on a sustainable basis is an important part of financial stability
# *4 29 See Werning and Lorenzoni (2023) for more on inflation as a form of 'conflict'
#  There is recent empirical evidence that when inflation expectations rise, income expectations rise by much less
#  30 There are other forms of redistribution linked to high inflation too, for example via the tax and benefits system, where thresholds and payments tend to be only partly inflation-linked
#  31 See statistics produced by the ONS for more details
#  It is of course also true that the lowest income households tend to be hit hardest by recessions
#  32 See the household disposable income statistics produced by the ONS
#  It is however true that the lowest paid jobs have seen large increases in nominal incomes linked to the National Living Wage
#  33 See my speech from earlier this year
#  34 The FPC undertook a detailed assessment of the financial stability risks of higher interest rates later in the year
#  My colleague Dave Ramsden talked about the theme in a recent speech
#  Bank of England Page 11 43
# Delivering low and stable inflation can of course require increases in interest rates
#  Such increases impact the financial system and it is vital to ensure the system is resilient to them
#  That is the job of the Financial Policy Committee (FPC)
#  The FPC's work on financial stability allows the MPC to get on with its job of maintaining monetary stability
#  Conclusion 44
# In summary, I intend to approach monetary policy decisions in the coming months paying great attention to how real world outcomes differ from our expectations and adjusting accordingly
#  Scenario analysis is a helpful policy tool against a backdrop of unprecedented shocks
#  45
# 1 will approach each vote humbly and pragmatically, with no pre-determined policy path in mind
#  But given what we know now, I can say that it will be important for monetary policy to be restrictive for an extended period in order to return inflation sustainably to the 2% target in the medium-term
#  I''d like to thank Danny Walker for his assistance in drafting these remarks, Matthew Naylor and Kate Reinold for their work on the scenarios, and Tim Jackson for inspiring the theme of the speech
#  I would also like to thank Andrew Bailey, John Barrdear, Lauren Barnes, Fabrizio Cadamagnani, Alan Castle, Swati Dhingra, Jon Hall, Richard Harrison, Neha Jain, Josh Martin, Rupal Patel, Huw Pill, Dave Ramsden, May Rostom, Martin Seneca and Fergal Shortall for their helpful input and comments
#  The views expressed here are not necessarily those of the Monetary Policy Committee (MPC) or the Financial Policy Committee (FPC)

# %%
for i in os.listdir("../Data/Speeches/speeches_by_central_bank/"):
    if i in df[df['Language']=='English']['CentralBank'].value_counts().index:
        print(i)
        speeches = df[(df['Language']=='English') & (df['CentralBank']==i)]#['text']#.values[0][:100]
        display(speeches)
        speeches.to_csv(f"../Data/Speeches/speeches_by_central_bank/{i}/{i}.csv", index=False, sep='\t')
# Out:
# Bank of Canada
#                                                      URL  \
# 1310   https://www.bankofcanada.ca/2004/03/adjusting-...
# 1311   https://www.bankofcanada.ca/2004/03/asia-globa...
# 1312   https://www.bankofcanada.ca/2020/08/closing-re...
# 1313   https://www.bankofcanada.ca/2002/05/convocatio...
# 1314   https://www.bankofcanada.ca/2001/05/opening-st...
# ...                                                  ...
# 28629            https://www.bis.org/review/r990528b.pdf
# 28634            https://www.bis.org/review/r990603b.pdf
# 28690            https://www.bis.org/review/r990927a.pdf
# 28729            https://www.bis.org/review/r991108a.pdf
# 28756            https://www.bis.org/review/r991210a.pdf
#
#                                                      PDF  \
# 1310                                                 NaN
# 1311                                                 NaN
# 1312   https://www.bankofcanada.ca/wp-content/uploads...
# 1313                                                 NaN
# 1314   https://www.bankofcanada.ca/wp-content/uploads...
# ...                                                  ...
# 28629            https://www.bis.org/review/r990528b.pdf
# 28634            https://www.bis.org/review/r990603b.pdf
# 28690            https://www.bis.org/review/r990927a.pdf
# 28729            https://www.bis.org/review/r991108a.pdf
# 28756            https://www.bis.org/review/r991210a.pdf
#
#                                                    Title  \
# 1310                 Adjusting to Global Economic Change
# 1311                         Asia and the Global Economy
# 1312                                     Closing remarks
# 1313                                 Convocation address
# 1314               Release of the Monetary Policy Report
# ...                                                  ...
# 28629  Mr Thiessen's statement on the Bank of Canada'...
# 28634  Mr Thiessen evaluates the performance of the C...
# 28690  Mr Thiessen gives an update on the Canadian ec...
# 28729  Mr Thiessen reviews the challenges for Canadia...
# 28756  Mr Thiessen clarifies some points regarding th...
#
#                                                 Subtitle        Date  \
# 1310   Remarks: David Dodge - An event hosted by the ...  2004-03-16
# 1311   Remarks: Paul Jenkins - University of British ...  2004-03-30
# 1312   Closing Remarks by Carolyn A. Wilkins Senior D...  2020-08-26
# 1313   Remarks: David Dodge - Graduating Class of the...  2002-05-24
# 1314                      Opening Statement: David Dodge  2001-05-01
# ...                                                  ...         ...
# 28629  Opening statement of the Governor of the Bank ...  1999-05-26
# 28634  Address by the Governor of the Bank of Canada,...  1999-06-02
# 28690  Speech by Mr Gordon Thiessen, Governor of the ...  1999-09-23
# 28729  Remarks by Mr Gordon Thiessen, Governor of the...  1999-11-02
# 28756  Remarks by Gordon Thiessen, Governor of the Ba...  1999-12-06
#
#             Authorname             Role  Gender     CentralBank Country  \
# 1310       David Dodge         Governor    Male  Bank of Canada     CAN
# 1311      Paul Jenkins  Deputy Governor    Male  Bank of Canada     CAN
# 1312   Carolyn Wilkins  Deputy Governor  Female  Bank of Canada     CAN
# 1313       David Dodge         Governor    Male  Bank of Canada     CAN
# 1314       David Dodge         Governor    Male  Bank of Canada     CAN
# ...                ...              ...     ...             ...     ...
# 28629  Gordon Thiessen         Governor    Male  Bank of Canada     CAN
# 28634  Gordon Thiessen         Governor    Male  Bank of Canada     CAN
# 28690  Gordon Thiessen         Governor    Male  Bank of Canada     CAN
# 28729  Gordon Thiessen         Governor    Male  Bank of Canada     CAN
# 28756  Gordon Thiessen         Governor    Male  Bank of Canada     CAN
#
#                                                     text text_original  \
# 1310   Adjusting to Global Economic Change Remarks Da...           NaN
# 1311   Asia and the Global Economy Remarks Paul Jenki...           NaN
# 1312   Closing Remarks by Carolyn A. Wilkins Senior D...           NaN
# 1313   Convocation address Remarks David Dodge - Form...           NaN
# 1314   Release of the Monetary Policy Report 1 May 20...           NaN
# ...                                                  ...           ...
# 28629  Mr Thiessens statement on the Bank of Canadas ...           NaN
# 28634  Mr Thiessen evaluates the performance of the C...           NaN
# 28690  Mr Thiessen gives an update on the Canadian ec...           NaN
# 28729  Mr Thiessen reviews the challenges for Canadia...           NaN
# 28756  Mr Thiessen clarifies some points regarding th...           NaN
#
#                                             Filename Language       Source
# 1310   can_adjusting-global-economic-change-16032004  English  CB websites
# 1311                can_asia-global-economy-30032004  English  CB websites
# 1312                  can_closing-remarks-2020-08-26  English  CB websites
# 1313                can_convocation-address-24052002  English  CB websites
# 1314                    can_opening-statement-010501  English  CB websites
# ...                                              ...      ...          ...
# 28629                                       r990528b  English          BIS
# 28634                                       r990603b  English          BIS
# 28690                                       r990927a  English          BIS
# 28729                                       r991108a  English          BIS
# 28756                                       r991210a  English          BIS
#
# [640 rows x 15 columns]
# Bank of England
#                                                      URL  \
# 6472   https://www.bankofengland.co.uk/speech/2002/a-...
# 6473   https://www.bankofengland.co.uk/speech/2004/a-...
# 6474   https://www.bankofengland.co.uk/speech/2004/so...
# 6475   https://www.bankofengland.co.uk/speech/2005/ch...
# 6476   https://www.bankofengland.co.uk/speech/2006/ch...
# ...                                                  ...
# 28637            https://www.bis.org/review/r990611a.pdf
# 28680            https://www.bis.org/review/r990913a.pdf
# 28712            https://www.bis.org/review/r991015b.pdf
# 28751            https://www.bis.org/review/r991206b.pdf
# 28754            https://www.bis.org/review/r991208a.pdf
#
#                                                      PDF  \
# 6472   https://www.bankofengland.co.uk/-/media/boe/fi...
# 6473   https://www.bankofengland.co.uk/-/media/boe/fi...
# 6474   https://www.bankofengland.co.uk/-/media/boe/fi...
# 6475   https://www.bankofengland.co.uk/-/media/boe/fi...
# 6476   https://www.bankofengland.co.uk/-/media/boe/fi...
# ...                                                  ...
# 28637            https://www.bis.org/review/r990611a.pdf
# 28680            https://www.bis.org/review/r990913a.pdf
# 28712            https://www.bis.org/review/r991015b.pdf
# 28751            https://www.bis.org/review/r991206b.pdf
# 28754            https://www.bis.org/review/r991208a.pdf
#
#                                                    Title  \
# 6472   A Picture of European Unemployment: Success an...
# 6473   A Picture of European Unemployment: Success an...
# 6474           Some Current Issues in UK Monetary Policy
# 6475                              Speech by Charles Bean
# 6476                              Jackson Hole Symposium
# ...                                                  ...
# 28637  Mr. George gives an address on recent changes ...
# 28680  the middle way  (Central Bank Articles and Spe...
# 28712  Mr King speaks about interest rates, policy an...
# 28751  Mr Clementi comments on the systemic aspects o...
# 28754  Mr George looks at past, present and future ch...
#
#                                                 Subtitle        Date  \
# 6472                                                 NaN  2002-12-06
# 6473                                                 NaN  2004-03-26
# 6474                                                 NaN  2004-07-28
# 6475                                                 NaN  2005-08-26
# 6476                                                 NaN  2006-08-26
# ...                                                  ...         ...
# 28637  Speech given by Mr E A J George, Governor of t...  1999-06-10
# 28680  Speech delivered by Mr Mervyn King, Deputy Gov...  1999-09-09
# 28712  Speech given by Mr Mervyn King, Deputy Governo...  1999-10-11
# 28751  Speech given by Mr David Clementi, Deputy Gove...  1999-12-02
# 28754  Speech given by Mr Eddie George, Governor of t...  1999-12-07
#
#              Authorname             Role Gender      CentralBank Country  \
# 6472    Stephen Nickell     Board member   Male  Bank of England     GBR
# 6473    Stephen Nickell     Board member   Male  Bank of England     GBR
# 6474       Charles Bean     Board member   Male  Bank of England     GBR
# 6475       Charles Bean     Board member   Male  Bank of England     GBR
# 6476       Charles Bean     Board member   Male  Bank of England     GBR
# ...                 ...              ...    ...              ...     ...
# 28637  Eddie A J George         Governor   Male  Bank of England     GBR
# 28680       Mervyn King  Deputy Governor   Male  Bank of England     GBR
# 28712       Mervyn King  Deputy Governor   Male  Bank of England     GBR
# 28751    David Clementi  Deputy Governor   Male  Bank of England     GBR
# 28754  Eddie A J George         Governor   Male  Bank of England     GBR
#
#                                                     text text_original  \
# 6472   A Picture of European Unemployment: Success an...           NaN
# 6473   A Picture of European Unemployment: Success an...           NaN
# 6474   Some Current Issues in UK Monetary Policy Spee...           NaN
# 6475   Speech given by Charles Bean, Chief Economist,...           NaN
# 6476   Jackson Hole Symposium Comments by Charles Bea...           NaN
# ...                                                  ...           ...
# 28637  Mr. George gives an address on recent changes ...           NaN
# 28680  Mr King gives a speech on reforming the intern...           NaN
# 28712  Mr King speaks about interest rates, policy an...           NaN
# 28751  Mr Clementi comments on the systemic aspects o...           NaN
# 28754  Mr George looks at past, present and future ch...           NaN
#
#                                                 Filename Language       Source
# 6472   gbr_2002_a-picture-of-european-unemployment-su...  English  CB websites
# 6473   gbr_2004_a-picture-of-european-unemployment-su...  English  CB websites
# 6474   gbr_2004_some-current-issues-in-uk-monetary-po...  English  CB websites
# 6475        gbr_2005_charles-bean-jackson-hole-symposium  English  CB websites
# 6476        gbr_2006_charles-bean-jackson-hole-symposium  English  CB websites
# ...                                                  ...      ...          ...
# 28637                                           r990611a  English          BIS
# 28680                                           r990913a  English          BIS
# 28712                                           r991015b  English          BIS
# 28751                                           r991206b  English          BIS
# 28754                                           r991208a  English          BIS
#
# [1354 rows x 15 columns]
# Board of Governors of the Federal Reserve
#                                                      URL  \
# 12456            https://www.bis.org/review/r000114a.pdf
# 12457            https://www.bis.org/review/r000117a.pdf
# 12458            https://www.bis.org/review/r000117b.pdf
# 12461            https://www.bis.org/review/r000124b.pdf
# 12471            https://www.bis.org/review/r000216a.pdf
# ...                                                  ...
# 35471  https://fraser.stlouisfed.org/title/statements...
# 35472  https://fraser.stlouisfed.org/title/statements...
# 35477  https://fraser.stlouisfed.org/title/statements...
# 35478  https://fraser.stlouisfed.org/title/statements...
# 35479  https://fraser.stlouisfed.org/title/statements...
#
#                                                      PDF  \
# 12456            https://www.bis.org/review/r000114a.pdf
# 12457            https://www.bis.org/review/r000117a.pdf
# 12458            https://www.bis.org/review/r000117b.pdf
# 12461            https://www.bis.org/review/r000124b.pdf
# 12471            https://www.bis.org/review/r000216a.pdf
# ...                                                  ...
# 35471  https://fraser.stlouisfed.org/files/docs/histo...
# 35472  https://fraser.stlouisfed.org/files/docs/histo...
# 35477  https://fraser.stlouisfed.org/files/docs/histo...
# 35478  https://fraser.stlouisfed.org/files/docs/histo...
# 35479  https://fraser.stlouisfed.org/files/docs/histo...
#
#                                                    Title  \
# 12456  Mr Ferguson compares Asian and Latin American ...
# 12457  Mr Greenspan discusses technology and the US e...
# 12458  Mr Gramlich focuses on inflation targeting  (C...
# 12461  Mr Meyer gives his views on the sustainability...
# 12471  Mr Greenspan gives a testimony on over-the-cou...
# ...                                                  ...
# 35471  Basel II and H.R. 2043 : Testimony before the ...
# 35472  Natural Gas Supply : Testimony before the Comm...
# 35477  Statement on His Renomination to the Board : T...
# 35478  Statement on His Renomination as Vice Chairman...
# 35479  Power Outages and the Financial System : Testi...
#
#                                                 Subtitle        Date  \
# 12456  Remarks by Mr Roger W Ferguson Jr, Vice-Chairm...  2000-01-07
# 12457  Remarks by Mr Alan Greenspan, Chairman of the ...  2000-01-13
# 12458  Remarks by Mr Edward M Gramlich, Member of the...  2000-01-13
# 12461  Remarks by Mr Laurence H Meyer, Member of the ...  2000-01-20
# 12471  Testimony of Mr Alan Greenspan, Chairman of th...  2000-02-10
# ...                                                  ...         ...
# 35471                                                NaN  2003-06-19
# 35472                                                NaN  2003-07-10
# 35477                                                NaN  2003-10-14
# 35478                                                NaN  2003-10-14
# 35479                                                NaN  2003-10-20
#
#               Authorname             Role Gender  \
# 12456   Roger W Ferguson  Deputy Governor   Male
# 12457     Alan Greenspan         Governor   Male
# 12458  Edward M Gramlich     Board member   Male
# 12461   Laurence H Meyer     Board member   Male
# 12471     Alan Greenspan         Governor   Male
# ...                  ...              ...    ...
# 35471   Roger W Ferguson  Deputy Governor   Male
# 35472     Alan Greenspan         Governor   Male
# 35477     Ben S Bernanke     Board member   Male
# 35478   Roger W Ferguson  Deputy Governor   Male
# 35479       Mark W Olson     Board member   Male
#
#                                      CentralBank Country  \
# 12456  Board of Governors of the Federal Reserve     USA
# 12457  Board of Governors of the Federal Reserve     USA
# 12458  Board of Governors of the Federal Reserve     USA
# 12461  Board of Governors of the Federal Reserve     USA
# 12471  Board of Governors of the Federal Reserve     USA
# ...                                          ...     ...
# 35471  Board of Governors of the Federal Reserve     USA
# 35472  Board of Governors of the Federal Reserve     USA
# 35477  Board of Governors of the Federal Reserve     USA
# 35478  Board of Governors of the Federal Reserve     USA
# 35479  Board of Governors of the Federal Reserve     USA
#
#                                                     text text_original  \
# 12456  Mr Ferguson compares Asian and Latin American ...           NaN
# 12457  Mr Greenspan discusses technology and the US e...           NaN
# 12458  Mr Gramlich focuses on inflation targeting Rem...           NaN
# 12461  Mr Meyer gives his views on the sustainability...           NaN
# 12471  Mr Greenspan gives a testimony on over-the-cou...           NaN
# ...                                                  ...           ...
# 35471  Testimony of Vice Chairman Roger W. Ferguson, ...           NaN
# 35472  For release on delivery\n10:00 a.m. EDT\nJuly ...           NaN
# 35477  For release on delivery\n10:00 a.m. EDT\nOctob...           NaN
# 35478  For release on delivery\n10:00 a.m. EDT\nOctob...           NaN
# 35479  Power outages and the financial system\nBefore...           NaN
#
#                                                Filename Language    Source
# 12456                                          r000114a  English       BIS
# 12457                                          r000117a  English       BIS
# 12458                                          r000117b  English       BIS
# 12461                                          r000124b  English       BIS
# 12471                                          r000216a  English       BIS
# ...                                                 ...      ...       ...
# 35471                            basel-ii-hr-2043-36988  English  Archives
# 35472                           natural-gas-supply-8794  English  Archives
# 35477                 statement-renomination-board-8885  English  Archives
# 35478  statement-renomination-vice-chairman-board-36942  English  Archives
# 35479              power-outages-financial-system-36585  English  Archives
#
# [2658 rows x 15 columns]
# Central Bank of the Philippines
#                                                      URL  \
# 11583  https://www.bsp.gov.ph/SitePages/MediaAndResea...
# 11584  https://www.bsp.gov.ph/SitePages/MediaAndResea...
# 11585  https://www.bsp.gov.ph/SitePages/MediaAndResea...
# 11586  https://www.bsp.gov.ph/SitePages/MediaAndResea...
# 11587  https://www.bsp.gov.ph/SitePages/MediaAndResea...
# ...                                                  ...
# 27833             http://www.bis.org/review/r230718o.htm
# 27847             http://www.bis.org/review/r230731f.htm
# 27880             http://www.bis.org/review/r230905h.htm
# 27998            https://www.bis.org/review/r231026h.htm
# 27999            https://www.bis.org/review/r231026j.htm
#
#                                                      PDF  \
# 11583  https://www.bsp.gov.ph/Lists/Speeches%20list/A...
# 11584  https://www.bsp.gov.ph/Lists/Speeches%20list/A...
# 11585  https://www.bsp.gov.ph/Lists/Speeches%20list/A...
# 11586  https://www.bsp.gov.ph/Lists/Speeches%20list/A...
# 11587  https://www.bsp.gov.ph/Lists/Speeches%20list/A...
# ...                                                  ...
# 27833             http://www.bis.org/review/r230718o.pdf
# 27847             http://www.bis.org/review/r230731f.pdf
# 27880             http://www.bis.org/review/r230905h.pdf
# 27998            https://www.bis.org/review/r231026h.pdf
# 27999            https://www.bis.org/review/r231026j.pdf
#
#                                                    Title  \
# 11583                   On the Maharlika Investment Fund
# 11584  A Conversation with the Financial Markets on P...
# 11585                Bringing Paleng-QR Ph Plus to Pasig
# 11586  Examining Economic Policymaking in the Philipp...
# 11587  From Nowhere to Now Here: The CRD as a Step To...
# ...                                                  ...
# 27833  Felipe M Medalla: Navigating the road ahead - ...
# 27847  Eli M Remolona: Navigating the road ahead - lo...
# 27880  Eli M Remolona: Rising to the challenge - the ...
# 27998  Stability, sustainability, and inclusivity for...
# 27999  Eli M Remolona: Welcome message - 2nd Digital ...
#
#                                                 Subtitle        Date  \
# 11583                                                NaN  2023-02-01
# 11584                                                NaN  2023-02-02
# 11585                                                NaN  2023-03-03
# 11586                                                NaN  2023-03-02
# 11587                                                NaN  2023-04-25
# ...                                                  ...         ...
# 27833  Speech by Mr Felipe M Medalla, Governor of Ban...  2023-07-03
# 27847  Speech by Mr Eli M Remolona Jr, Governor of Ba...  2023-07-28
# 27880  Speech by Mr Eli M Remolona, Jr, Governor of B...  2023-08-14
# 27998  Speech by Mr Eli M Remolona, Jr, Governor of B...  2023-09-14
# 27999  Welcome message by Mr Eli M Remolona, Jr, Gove...  2023-10-24
#
#              Authorname             Role Gender  \
# 11583  Felipe M Medalla         Governor   Male
# 11584  Felipe M Medalla         Governor   Male
# 11585  Felipe M Medalla         Governor   Male
# 11586  Felipe M Medalla         Governor   Male
# 11587  Felipe M Medalla         Governor   Male
# ...                 ...              ...    ...
# 27833  Felipe M Medalla         Governor   Male
# 27847    Eli M Remolona  Deputy Governor   Male
# 27880    Eli M Remolona  Deputy Governor   Male
# 27998    Eli M Remolona         Governor   Male
# 27999    Eli M Remolona  Deputy Governor   Male
#
#                            CentralBank Country  \
# 11583  Central Bank of the Philippines     PHL
# 11584  Central Bank of the Philippines     PHL
# 11585  Central Bank of the Philippines     PHL
# 11586  Central Bank of the Philippines     PHL
# 11587  Central Bank of the Philippines     PHL
# ...                                ...     ...
# 27833  Central Bank of the Philippines     PHL
# 27847  Central Bank of the Philippines     PHL
# 27880  Central Bank of the Philippines     PHL
# 27998  Central Bank of the Philippines     PHL
# 27999  Central Bank of the Philippines     PHL
#
#                                                     text text_original  \
# 11583  Media and Research - Speeches On the Maharlika...           NaN
# 11584  Media and Research - Speeches A Conversation w...           NaN
# 11585  Magandang umaga sa inyong lahat. I knew I was ...           NaN
# 11586  Media and Research - Speeches Examining Econom...           NaN
# 11587  Media and Research - Speeches From Nowhere to ...           NaN
# ...                                                  ...           ...
# 27833  Felipe M Medalla: Navigating the road ahead - ...           NaN
# 27847  Eli M Remolona: Navigating the road ahead - lo...           NaN
# 27880  Eli M Remolona: Rising to the challenge - the ...           NaN
# 27998  Eli M Remolona: Stability, sustainability, and...           NaN
# 27999  Eli M Remolona: Welcome message - 2nd Digital ...           NaN
#
#                     Filename Language       Source
# 11583  phl_bsp-speeches-1003  English  CB websites
# 11584  phl_bsp-speeches-1004  English  CB websites
# 11585  phl_bsp-speeches-1010  English  CB websites
# 11586  phl_bsp-speeches-1011  English  CB websites
# 11587  phl_bsp-speeches-1017  English  CB websites
# ...                      ...      ...          ...
# 27833               r230718o  English          BIS
# 27847               r230731f  English          BIS
# 27880               r230905h  English          BIS
# 27998               r231026h  English          BIS
# 27999               r231026j  English          BIS
#
# [990 rows x 15 columns]
# European Central Bank
#                                                      URL  \
# 2976   https://www.ecb.europa.eu/press/key/date/2000/...
# 2977   https://www.ecb.europa.eu/press/key/date/2000/...
# 2978   https://www.ecb.europa.eu/press/key/date/2000/...
# 2979   https://www.ecb.europa.eu/press/key/date/2000/...
# 2980   https://www.ecb.europa.eu/press/key/date/2000/...
# ...                                                  ...
# 28610            https://www.bis.org/review/r990510b.htm
# 28657            https://www.bis.org/review/r990716a.htm
# 28681            https://www.bis.org/review/r990914a.htm
# 28705            https://www.bis.org/review/r991012b.htm
# 28731            https://www.bis.org/review/r991109a.htm
#
#                                            PDF  \
# 2976                                       NaN
# 2977                                       NaN
# 2978                                       NaN
# 2979                                       NaN
# 2980                                       NaN
# ...                                        ...
# 28610  https://www.bis.org/review/r990510b.pdf
# 28657  https://www.bis.org/review/r990716a.pdf
# 28681  https://www.bis.org/review/r990914a.pdf
# 28705  https://www.bis.org/review/r991012b.pdf
# 28731  https://www.bis.org/review/r991109a.pdf
#
#                                                    Title  \
# 2976                              One year with the euro
# 2977   Opening Remarks at a Hearing of the Committee ...
# 2978                The international impact of the euro
# 2979   The role of the central bank in encouraging an...
# 2980   The euro area - first experience and perspectives
# ...                                                  ...
# 28610  Mr Duisenberg reports on the outcome of the la...
# 28657  Mr Duisenberg's statement on the European Unio...
# 28681  Mr Duisenberg reports on the outcome of the la...
# 28705  Mr Duisenberg and Mr Noyer report on the outco...
# 28731  Mr Duisenberg reports on the outcome of the la...
#
#                                                 Subtitle        Date  \
# 2976   Speech delivered by Dr Sirkka Hmlinen,     Mem...  2000-01-08
# 2977   Professor Otmar Issing,  Member of the Board o...  2000-01-10
# 2978   Speech delivered by Christian Noyer,      Vice...  2000-01-13
# 2979   Speech given by Christian Noyer,     Vice-Pres...  2000-01-21
# 2980   by Professor Otmar Issing,  Member of the Boar...  2000-01-26
# ...                                                  ...         ...
# 28610                                                NaN  1999-05-06
# 28657                                                NaN  1999-07-15
# 28681                                                NaN  1999-09-09
# 28705                                                NaN  1999-10-07
# 28731                                                NaN  1999-11-04
#
#                 Authorname             Role  Gender            CentralBank  \
# 2976        Sirkka Hmlinen     Board member  Female  European Central Bank
# 2977          Otmar Issing     Board member    Male  European Central Bank
# 2978       Christian Noyer  Deputy Governor    Male  European Central Bank
# 2979       Christian Noyer  Deputy Governor    Male  European Central Bank
# 2980          Otmar Issing     Board member    Male  European Central Bank
# ...                    ...              ...     ...                    ...
# 28610  Willem F Duisenberg     Board member  Female  European Central Bank
# 28657  Willem F Duisenberg     Board member  Female  European Central Bank
# 28681  Willem F Duisenberg     Board member  Female  European Central Bank
# 28705  Willem F Duisenberg     Board member  Female  European Central Bank
# 28731  Willem F Duisenberg     Board member  Female  European Central Bank
#
#       Country                                               text  \
# 2976      ECB  One year with the euro Speech delivered by Dr ...
# 2977      ECB  Opening Remarks at a Hearing of the Committee ...
# 2978      ECB  The international impact of the euro Speech de...
# 2979      ECB  The role of the central bank in encouraging an...
# 2980      ECB  The euro area - first experience and perspecti...
# ...       ...                                                ...
# 28610     ECB  Mr Duisenberg reports on the outcome of the la...
# 28657     ECB  Mr Duisenbergs statement on the European Union...
# 28681     ECB  Mr Duisenberg reports on the outcome of the la...
# 28705     ECB  Mr Duisenberg and Mr Noyer report on the outco...
# 28731     ECB  Mr Duisenberg reports on the outcome of the la...
#
#       text_original       Filename Language       Source
# 2976            NaN  ecb_000108.en  English  CB websites
# 2977            NaN  ecb_000110.en  English  CB websites
# 2978            NaN  ecb_000113.en  English          BIS
# 2979            NaN  ecb_000121.en  English          BIS
# 2980            NaN  ecb_000126.en  English  CB websites
# ...             ...            ...      ...          ...
# 28610           NaN       r990510b  English          BIS
# 28657           NaN       r990716a  English          BIS
# 28681           NaN       r990914a  English          BIS
# 28705           NaN       r991012b  English          BIS
# 28731           NaN       r991109a  English          BIS
#
# [2522 rows x 15 columns]
# Federal Reserve Bank of Atlanta
#                                                      URL  \
# 21557            https://www.bis.org/review/r150210f.htm
# 21558            https://www.bis.org/review/r150210g.htm
# 30992  https://www.atlantafed.org/news/speeches/2000/...
# 30994  https://www.atlantafed.org/news/speeches/2000/...
# 31000  https://www.atlantafed.org/news/speeches/2000/...
# ...                                                  ...
# 34008  https://fraser.stlouisfed.org/files/docs/histo...
# 34009  https://fraser.stlouisfed.org/files/docs/histo...
# 34010  https://fraser.stlouisfed.org/files/docs/histo...
# 34011  https://fraser.stlouisfed.org/files/docs/histo...
# 35486  https://fraser.stlouisfed.org/title/statements...
#
#                                                      PDF  \
# 21557            https://www.bis.org/review/r150210f.pdf
# 21558            https://www.bis.org/review/r150210g.pdf
# 30992                                                NaN
# 30994                                                NaN
# 31000                                                NaN
# ...                                                  ...
# 34008  https://fraser.stlouisfed.org/title/statements...
# 34009  https://fraser.stlouisfed.org/title/statements...
# 34010  https://fraser.stlouisfed.org/title/statements...
# 34011  https://fraser.stlouisfed.org/title/statements...
# 35486  https://fraser.stlouisfed.org/files/docs/histo...
#
#                                                    Title  \
# 21557            A potentially momentous year for policy
# 21558  Considerations on the path to policy normaliza...
# 30992                      The Economic Outlook for 2000
# 30994                     An Outlook - And a Look Within
# 31000  The Role of Low Inflation in the Current Expan...
# ...                                                  ...
# 34008  The Economic Outlook for the United States and...
# 34009  The Economic Outlook for the United States and...
# 34010  Latin America's Economic Boom: The U.S. Perspe...
# 34011  The National and International Economic Outloo...
# 35486  Beyond Short-Term Interests : Atlanta Regional...
#
#                                                 Subtitle        Date  \
# 21557  Speech by Mr Dennis Lockhart, President and Ch...  2015-01-12
# 21558  Speech by Mr Dennis Lockhart, President and Ch...  2015-02-06
# 30992                                                NaN  2000-01-24
# 30994                                                NaN  2000-03-03
# 31000                                                NaN  2000-06-05
# ...                                                  ...         ...
# 34008                                                NaN  1995-07-24
# 34009                                                NaN  1995-08-10
# 34010                                                NaN  1995-09-15
# 34011                                                NaN  1995-09-07
# 35486                                                NaN  2003-11-21
#
#                Authorname      Role Gender                      CentralBank  \
# 21557     Dennis Lockhart  Governor   Male  Federal Reserve Bank of Atlanta
# 21558     Dennis Lockhart  Governor   Male  Federal Reserve Bank of Atlanta
# 30992          Jack Guynn  Governor   Male  Federal Reserve Bank of Atlanta
# 30994          Jack Guynn  Governor   Male  Federal Reserve Bank of Atlanta
# 31000          Jack Guynn  Governor   Male  Federal Reserve Bank of Atlanta
# ...                   ...       ...    ...                              ...
# 34008  Robert P Forrestal  Governor   Male  Federal Reserve Bank of Atlanta
# 34009  Robert P Forrestal  Governor   Male  Federal Reserve Bank of Atlanta
# 34010  Robert P Forrestal  Governor   Male  Federal Reserve Bank of Atlanta
# 34011  Robert P Forrestal  Governor   Male  Federal Reserve Bank of Atlanta
# 35486          Jack Guynn  Governor   Male  Federal Reserve Bank of Atlanta
#
#       Country                                               text  \
# 21557     USA  Dennis Lockhart: A potentially momentous year ...
# 21558     USA  Dennis Lockhart: Considerations on the path to...
# 30992     USA  SPEECHES The Economic Outlook for 2000 Remarks...
# 30994     USA  SPEECHES An Outlook - And a Look Within Remark...
# 31000     USA  SPEECHES The Role of Low Inflation in the Curr...
# ...       ...                                                ...
# 34008     USA  THE ECONOMIC OUTLOOK FOR THE UNITED STATES AND...
# 34009     USA  THE ECONOMIC OUTLOOK FOR THE UNITED STATES AND...
# 34010     USA  LATIN AMERICA'S ECONOMIC BOOM: THE U.S. PERSPE...
# 34011     USA  THE NATIONAL AND INTERNATIONAL ECONOMIC OUTLOO...
# 35486     USA  Speeches\n\nBeyond Short-Term Interests\n\nJac...
#
#       text_original                            Filename Language       Source
# 21557           NaN                            r150210f  English          BIS
# 21558           NaN                            r150210g  English          BIS
# 30992           NaN                    usa_000124-guynn  English  CB websites
# 30994           NaN                    usa_000303-guynn  English  CB websites
# 31000           NaN                    usa_000605-guynn  English  CB websites
# ...             ...                                 ...      ...          ...
# 34008           NaN    usa_robert_p_forrestal_1995_7_24  English     Archives
# 34009           NaN    usa_robert_p_forrestal_1995_8_10  English     Archives
# 34010           NaN    usa_robert_p_forrestal_1995_9_15  English     Archives
# 34011           NaN     usa_robert_p_forrestal_1995_9_7  English     Archives
# 35486           NaN  beyond-short-term-interests-521702  English     Archives
#
# [527 rows x 15 columns]
# Federal Reserve Bank of Boston
#                                                      URL  \
# 17687            https://www.bis.org/review/r100507e.pdf
# 18417            https://www.bis.org/review/r110408e.pdf
# 18422            https://www.bis.org/review/r110411e.pdf
# 18543            https://www.bis.org/review/r110603d.pdf
# 18547            https://www.bis.org/review/r110606b.pdf
# ...                                                  ...
# 34727  https://www.bostonfed.org/news-and-events/spee...
# 34728  https://www.bostonfed.org/news-and-events/spee...
# 34731  https://www.bostonfed.org/news-and-events/spee...
# 34854  https://www.bostonfed.org/news-and-events/spee...
# 34913  https://www.bostonfed.org/news-and-events/spee...
#
#                                                      PDF  \
# 17687            https://www.bis.org/review/r100507e.pdf
# 18417            https://www.bis.org/review/r110408e.pdf
# 18422            https://www.bis.org/review/r110411e.pdf
# 18543            https://www.bis.org/review/r110603d.pdf
# 18547            https://www.bis.org/review/r110606b.pdf
# ...                                                  ...
# 34727                                                NaN
# 34728                                                NaN
# 34731                                                NaN
# 34854  https://www.bostonfed.org/-/media/Documents/ne...
# 34913                                                NaN
#
#                                                    Title  \
# 17687     Considering the routes to a policy destination
# 18417      Two key questions about the economic recovery
# 18422  The role of "financial myths" in financial crises
# 18543  A look inside a key economic debate - how shou...
# 18547  A US perspective on strengthening financial st...
# ...                                                  ...
# 34727  U.S. Retail Payments: Change, Challenge and Op...
# 34728  U.S. Retail Payments: Opportunities and Challe...
# 34731                Vermont Economic Outlook Conference
# 34854  Preserving Homeownership: Progress Needed to P...
# 34913         Working Women: The Dream and the Challenge
#
#                                                 Subtitle        Date  \
# 17687  Speech by Mr Eric S Rosengren, President and C...  2010-05-05
# 18417  Remarks by Mr Eric S Rosengren, President and ...  2011-01-14
# 18422  Remarks by Mr Eric S Rosengren, President and ...  2011-02-28
# 18543  Remarks by Mr Eric S Rosengren, President and ...  2011-05-04
# 18547  Speech by Mr Eric S Rosengren, President and C...  2011-05-24
# ...                                                  ...         ...
# 34727                                                NaN  2002-05-08
# 34728                                                NaN  2004-06-17
# 34731                                                NaN  2003-01-10
# 34854                                                NaN  2009-07-16
# 34913                                                NaN  2000-12-04
#
#              Authorname               Role  Gender  \
# 17687  Eric S Rosengren           Governor    Male
# 18417  Eric S Rosengren           Governor    Male
# 18422  Eric S Rosengren           Governor    Male
# 18543  Eric S Rosengren           Governor    Male
# 18547  Eric S Rosengren           Governor    Male
# ...                 ...                ...     ...
# 34727   Cathy E Minehan           Governor  Female
# 34728   Cathy E Minehan           Governor  Female
# 34731   Cathy E Minehan           Governor  Female
# 34854       Paul Willen  Senior management    Male
# 34913   Cathy E Minehan           Governor  Female
#
#                           CentralBank Country  \
# 17687  Federal Reserve Bank of Boston     USA
# 18417  Federal Reserve Bank of Boston     USA
# 18422  Federal Reserve Bank of Boston     USA
# 18543  Federal Reserve Bank of Boston     USA
# 18547  Federal Reserve Bank of Boston     USA
# ...                               ...     ...
# 34727  Federal Reserve Bank of Boston     USA
# 34728  Federal Reserve Bank of Boston     USA
# 34731  Federal Reserve Bank of Boston     USA
# 34854  Federal Reserve Bank of Boston     USA
# 34913  Federal Reserve Bank of Boston     USA
#
#                                                     text text_original  \
# 17687  Eric S Rosengren: Considering the routes to a ...           NaN
# 18417  Eric S Rosengren: Two key questions about the ...           NaN
# 18422  Eric S Rosengren: The role of financial myths ...           NaN
# 18543  Eric S Rosengren: A look inside a key economic...           NaN
# 18547  Eric S Rosengren: A US perspective on strength...           NaN
# ...                                                  ...           ...
# 34727  U.S. Retail Payments: Change, Challenge and Op...           NaN
# 34728  U.S. Retail Payments: Opportunities and Challe...           NaN
# 34731  Vermont Economic Outlook Conference By Cathy E...           NaN
# 34854  TESTIMONY OF Paul S. Willen Senior Economist a...           NaN
# 34913  Working Women: The Dream and the Challenge By ...           NaN
#
#                                                 Filename Language       Source
# 17687                                           r100507e  English          BIS
# 18417                                           r110408e  English          BIS
# 18422                                           r110411e  English          BIS
# 18543                                           r110603d  English          BIS
# 18547                                           r110606b  English          BIS
# ...                                                  ...      ...          ...
# 34727  usa_us-retail-payments-change-challenge-and-op...  English  CB websites
# 34728  usa_us-retail-payments-opportunities-and-chall...  English  CB websites
# 34731            usa_vermont-economic-outlook-conference  English  CB websites
# 34854                                   usa_willen071609  English  CB websites
# 34913      usa_working-women-the-dream-and-the-challenge  English  CB websites
#
# [231 rows x 15 columns]
# Federal Reserve Bank of Chicago
#                                                      URL  \
# 18756            https://www.bis.org/review/r110916e.pdf
# 18833            https://www.bis.org/review/r111019c.pdf
# 19038            https://www.bis.org/review/r120112a.pdf
# 19162            https://www.bis.org/review/r120319a.pdf
# 19163            https://www.bis.org/review/r120319b.pdf
# ...                                                  ...
# 35474  https://fraser.stlouisfed.org/title/statements...
# 35475  https://fraser.stlouisfed.org/title/statements...
# 35480  https://fraser.stlouisfed.org/title/statements...
# 35482  https://fraser.stlouisfed.org/title/statements...
# 35485  https://fraser.stlouisfed.org/title/statements...
#
#                                                      PDF  \
# 18756            https://www.bis.org/review/r110916e.pdf
# 18833            https://www.bis.org/review/r111019c.pdf
# 19038            https://www.bis.org/review/r120112a.pdf
# 19162            https://www.bis.org/review/r120319a.pdf
# 19163            https://www.bis.org/review/r120319b.pdf
# ...                                                  ...
# 35474  https://fraser.stlouisfed.org/files/docs/histo...
# 35475  https://fraser.stlouisfed.org/files/docs/histo...
# 35480  https://fraser.stlouisfed.org/files/docs/histo...
# 35482  https://fraser.stlouisfed.org/files/docs/histo...
# 35485  https://fraser.stlouisfed.org/files/docs/histo...
#
#                                                    Title  \
# 18756  The Fed's dual mandate responsibilities and ch...
# 18833  The Fed's dual mandate responsibilities - main...
# 19038      A risk management approach to monetary policy
# 19162                     Managing monetary policy risks
# 19163  Monetary policy communications and forward gui...
# ...                                                  ...
# 35474  Opening Remarks, Is Midwest Manufacturing at a...
# 35475  U.S. Economic Outlook : Business Week CEO Lead...
# 35480  Opening Remarks, Conference on Geography of Au...
# 35482  Formulating and Communicating U.S. Monetary Po...
# 35485  U.S. Economic Outlook : [Speech Before the] Ch...
#
#                                                 Subtitle        Date  \
# 18756  Speech by Charles L Evans, President of the Fe...  2011-09-07
# 18833  Speech by Charles L Evans, President of the Fe...  2011-10-17
# 19038  Speech by Charles L Evans, President of the Fe...  2011-12-05
# 19162  Speech by Mr Charles L Evans, President of the...  2012-01-11
# 19163  Speech by Mr Charles L Evans, President of the...  2012-03-16
# ...                                                  ...         ...
# 35474                                                NaN  2003-09-30
# 35475                                                NaN  2003-10-02
# 35480                                                NaN  2003-11-03
# 35482                                                NaN  2003-11-13
# 35485                                                NaN  2003-11-20
#
#             Authorname      Role Gender                      CentralBank  \
# 18756  Charles L Evans  Governor   Male  Federal Reserve Bank of Chicago
# 18833  Charles L Evans  Governor   Male  Federal Reserve Bank of Chicago
# 19038  Charles L Evans  Governor   Male  Federal Reserve Bank of Chicago
# 19162  Charles L Evans  Governor   Male  Federal Reserve Bank of Chicago
# 19163  Charles L Evans  Governor   Male  Federal Reserve Bank of Chicago
# ...                ...       ...    ...                              ...
# 35474   Michael Moskow  Governor   Male  Federal Reserve Bank of Chicago
# 35475   Michael Moskow  Governor   Male  Federal Reserve Bank of Chicago
# 35480   Michael Moskow  Governor   Male  Federal Reserve Bank of Chicago
# 35482   Michael Moskow  Governor   Male  Federal Reserve Bank of Chicago
# 35485   Michael Moskow  Governor   Male  Federal Reserve Bank of Chicago
#
#       Country                                               text  \
# 18756     USA  Charles L Evans: The Feds dual mandate respons...
# 18833     USA  Charles L Evans: The Feds dual mandate respons...
# 19038     USA  Charles L Evans: A risk management approach to...
# 19162     USA  Charles L Evans: Managing monetary policy risk...
# 19163     USA  Charles L Evans: Monetary policy communication...
# ...       ...                                                ...
# 35474     USA  IS MIDWEST MANUFACTURING AT A CROSSROADS?\nFED...
# 35475     USA  BUSINESS WEEK CEO LEADERSHIP FORUM\n\nEvanston...
# 35480     USA  CONFERENCE ON GEOGRAPHY OF AUTO PRODUCTION\nWI...
# 35482     USA  9TH INTERNATIONAL FINANCIAL AND ECONOMIC FORUM...
# 35485     USA  CHICAGOLAND CHAMBER OF COMMERCE / WBBM NEWSRAD...
#
#       text_original                                           Filename  \
# 18756           NaN                                           r110916e
# 18833           NaN                                           r111019c
# 19038           NaN                                           r120112a
# 19162           NaN                                           r120319a
# 19163           NaN                                           r120319b
# ...             ...                                                ...
# 35474           NaN  opening-remarks-midwest-manufacturing-a-crossr...
# 35475           NaN                         us-economic-outlook-581486
# 35480           NaN  opening-remarks-conference-geography-auto-prod...
# 35482           NaN  formulating-communicating-us-monetary-policy-5...
# 35485           NaN                         us-economic-outlook-581490
#
#       Language    Source
# 18756  English       BIS
# 18833  English       BIS
# 19038  English       BIS
# 19162  English       BIS
# 19163  English       BIS
# ...        ...       ...
# 35474  English  Archives
# 35475  English  Archives
# 35480  English  Archives
# 35482  English  Archives
# 35485  English  Archives
#
# [418 rows x 15 columns]
# Federal Reserve Bank of Cleveland
#                                                      URL  \
# 31964  https://www.clevelandfed.org/en/newsroom-and-e...
# 33028  https://fraser.stlouisfed.org/files/docs/histo...
# 33029  https://fraser.stlouisfed.org/files/docs/histo...
# 33030  https://fraser.stlouisfed.org/files/docs/histo...
# 33031  https://fraser.stlouisfed.org/files/docs/histo...
# ...                                                  ...
# 35334  https://fraser.stlouisfed.org/title/statements...
# 35340  https://fraser.stlouisfed.org/title/statements...
# 35341  https://fraser.stlouisfed.org/title/statements...
# 35346  https://fraser.stlouisfed.org/title/statements...
# 35378  https://fraser.stlouisfed.org/title/statements...
#
#                                                      PDF  \
# ...
# 35157                  Statement, Audio Press Conference
#
#                                                 Subtitle        Date  \
# 31947               Northwest Arkansas Convention Center  2008-06-04
# 31948               Fluno Center for Executive Education  2008-06-06
# 31949  Macroeconomics Advisers Quarterly Outlook Meeting  2008-06-11
# 31951                                                NaN  2011-04-26
# 31956                                                NaN  2013-05-30
# ...                                                  ...         ...
# 35126                                                NaN  1997-04-25
# 35130                                                NaN  1997-06-04
# 35143                                                NaN  1997-10-07
# 35146                                                NaN  1997-10-28
# 35157                                                NaN  1998-01-21
#
#             Authorname      Role Gender                       CentralBank  \
# 31947    James Bullard  Governor   Male  Federal Reserve Bank of St Louis
# 31948    James Bullard  Governor   Male  Federal Reserve Bank of St Louis
# 31949    James Bullard  Governor   Male  Federal Reserve Bank of St Louis
# 31951    James Bullard  Governor   Male  Federal Reserve Bank of St Louis
# 31956    James Bullard  Governor   Male  Federal Reserve Bank of St Louis
# ...                ...       ...    ...                               ...
# 35126  Thomas C Melzer  Governor   Male  Federal Reserve Bank of St Louis
# 35130  Thomas C Melzer  Governor   Male  Federal Reserve Bank of St Louis
# 35143  Thomas C Melzer  Governor   Male  Federal Reserve Bank of St Louis
# 35146  Thomas C Melzer  Governor   Male  Federal Reserve Bank of St Louis
# 35157  Thomas C Melzer  Governor   Male  Federal Reserve Bank of St Louis
#
#       Country                                               text  \
# 31947     USA  7:00 a.m. CDT June 4, 2008 A Perspective on th...
# 31948     USA  Embargoed until 12:30 p.m. CDT June 6, 2008 Re...
# 31949     USA  12:00 p.m CDT June 11, 2008 Remarks on the U.S...
# 31951     USA  2010 Annual Report 2010 Home Many Moving Parts...
# 31956     USA  2012 Annual Report 2012 Home President's Messa...
# ...       ...                                                ...
# 35126     USA                           EMBARGOED UNTIL 7:00 ...
# 35130     USA                           EMBARGOED UNTIL 9:15 ...
# 35143     USA                          EMBARGOED UNTIL 8:00 a...
# 35146     USA                     EMBARGOED UNTIL 11:00 a.m.,...
# 35157     USA                           EMBARGOED UNTIL CONCL...
#
#       text_original                                           Filename  \
# 31947           NaN                                     usa_2008-06-04
# 31948           NaN                                     usa_2008-06-06
# 31949           NaN                                     usa_2008-06-11
# 31951           NaN                                           usa_2010
# 31956           NaN                                 usa_2012_president
# ...             ...                                                ...
# 35126           NaN  electronic-money-inflation-role-fed-payments-s...
# 35130           NaN   a-credible-monetary-policy-sustains-growth-18803
# 35143           NaN          would-lower-inflation-reduce-growth-18804
# 35146           NaN              price-stability-policies-growth-18805
# 35157           NaN             statement-audio-press-conference-18806
#
#       Language       Source
# 31947  English  CB websites
# 31948  English  CB websites
# 31949  English  CB websites
# 31951  English  CB websites
# 31956  English  CB websites
# ...        ...          ...
# 35126  English     Archives
# 35130  English     Archives
# 35143  English     Archives
# 35146  English     Archives
# 35157  English     Archives
#
# [252 rows x 15 columns]
# Monetary Authority of Singapore
#                                                      URL  \
# 12470            https://www.bis.org/review/r000203c.pdf
# 12513            https://www.bis.org/review/r000405b.pdf
# 12570            https://www.bis.org/review/r000626b.pdf
# 12587            https://www.bis.org/review/r000803b.pdf
# 12602            https://www.bis.org/review/r000907a.pdf
# ...                                                  ...
# 29590  https://www.mas.gov.sg/news/speeches/2023/stre...
# 29591  https://www.mas.gov.sg/news/speeches/2023/over...
# 29592  https://www.mas.gov.sg/news/speeches/2023/sing...
# 29593  https://www.mas.gov.sg/news/speeches/2022/resp...
# 29594  https://www.mas.gov.sg/news/speeches/2022/rema...
#
#                                            PDF  \
# 12470  https://www.bis.org/review/r000203c.pdf
# 12513  https://www.bis.org/review/r000405b.pdf
# 12570  https://www.bis.org/review/r000626b.pdf
# 12587  https://www.bis.org/review/r000803b.pdf
# 12602  https://www.bis.org/review/r000907a.pdf
# ...                                        ...
# 29590                                      NaN
# 29591                                      NaN
# 29592                                      NaN
# 29593                                      NaN
# 29594                                      NaN
#
#                                                    Title  \
# 12470  Mr Lim gives a policymaker's perspective on th...
# 12513  Financial sector liberalisation - going global...
# 12570  Separation of financial and non-financial acti...
# 12587  The economic outlook and monetary policy in Si...
# 12602  Capital markets in the new economy  (Central B...
# ...                                                  ...
# 29590  Strengthening Supervision Through Collaborativ...
# 29591  Speech by Mr Tan Kiat How, Senior Minister of ...
# 29592  "Singapore's National AI Programme in the Real...
# 29593  Responding to a Perfect Long Storm  Transcript...
# 29594  Remarks by Mr Tharman Shanmugaratnam, Senior M...
#
#                                                 Subtitle        Date  \
# 12470  Opening remarks by Mr Lim Hng Kiang, Member of...  2000-02-02
# 12513  Speech by Mr Lee Hsien Loong, Chairman of the ...  2000-04-03
# 12570  Speech by DPM Lee Hsien Loong, Chairman of the...  2000-06-21
# 12587  Statement by Mr Koh Yong Guan, Managing Direct...  2000-07-27
# 12602  Speech by Mr Lee Hsien Loong, Chairman of the ...  2000-09-06
# ...                                                  ...         ...
# 29590                                                NaN  2023-03-22
# 29591                                                NaN  2023-05-23
# 29592                                                NaN  2023-11-14
# 29593                                                NaN  2022-03-09
# 29594                                                NaN  2022-12-02
#
#                    Authorname               Role Gender  \
# 12470           Lim Hng Kiang       Board member   Male
# 12513         Lee Hsien Loong           Governor   Male
# 12570         Lee Hsien Loong           Governor   Male
# 12587           Koh yong Guan  Senior management   Male
# 12602         Lee Hsien Loong           Governor   Male
# ...                       ...                ...    ...
# 29590           Tan Keng Heng  Senior management   Male
# 29591            Tan Kiat How       Board member   Male
# 29592            Tan Kiat How       Board member   Male
# 29593  Tharman Shanmugaratnam           Governor   Male
# 29594  Tharman Shanmugaratnam           Governor   Male
#
#                            CentralBank Country  \
# 12470  Monetary Authority of Singapore     SGP
# 12513  Monetary Authority of Singapore     SGP
# 12570  Monetary Authority of Singapore     SGP
# 12587  Monetary Authority of Singapore     SGP
# 12602  Monetary Authority of Singapore     SGP
# ...                                ...     ...
# 29590  Monetary Authority of Singapore     SGP
# 29591  Monetary Authority of Singapore     SGP
# 29592  Monetary Authority of Singapore     SGP
# 29593  Monetary Authority of Singapore     SGP
# 29594  Monetary Authority of Singapore     SGP
#
#                                                     text text_original  \
# 12470  Mr Lim gives a policymakers perspective on the...           NaN
# 12513  Lee Hsien Loong: Financial sector liberalisati...           NaN
# 12570  Lee Hsien Loong: Separation of financial and n...           NaN
# 12587  Koh Yong Guan: The economic outlook and moneta...           NaN
# 12602  Lee Hsien Loong: Capital markets in the new ec...           NaN
# ...                                                  ...           ...
# 29590  Strengthening Supervision Through Collaborativ...           NaN
# 29591  Speech by Mr Tan Kiat How, Senior Minister of ...           NaN
# 29592  "Singapore's National Al Programme in the Real...           NaN
# 29593  Responding to a Perfect Long Storm - Transcrip...           NaN
# 29594  Remarks by Mr Tharman Shanmugaratnam, Senior M...           NaN
#
#                                Filename Language       Source
# 12470                          r000203c  English          BIS
# 12513                          r000405b  English          BIS
# 12570                          r000626b  English          BIS
# 12587                          r000803b  English          BIS
# 12602                          r000907a  English          BIS
# ...                                 ...      ...          ...
# 29590           sgp_tan_keng_heng_45007  English  CB websites
# 29591            sgp_tan_kiat_how_45069  English  CB websites
# 29592            sgp_tan_kiat_how_45244  English  CB websites
# 29593  sgp_tharman_shanmugaratnam_44629  English  CB websites
# 29594  sgp_tharman_shanmugaratnam_44897  English  CB websites
#
# [914 rows x 15 columns]
# Reserve Bank of India
#                                                      URL  \
# 7917   https://www.rbi.org.in/Scripts/BS_SpeechesView...
# 7918   https://www.rbi.org.in/Scripts/BS_SpeechesView...
# 7919   https://www.rbi.org.in/Scripts/BS_SpeechesView...
# 7920   https://www.rbi.org.in/Scripts/BS_SpeechesView...
# 7921   https://www.rbi.org.in/Scripts/BS_SpeechesView...
# ...                                                  ...
# 28531            https://www.bis.org/review/r981221b.pdf
# 28549            https://www.bis.org/review/r990205b.pdf
# 28560            https://www.bis.org/review/r990215c.pdf
# 28631            https://www.bis.org/review/r990531b.pdf
# 28638            https://www.bis.org/review/r990615b.pdf
#
#                                                      PDF  \
# 7917   https://rbidocs.rbi.org.in/rdocs/Speeches/PDFs...
# 7918   https://rbidocs.rbi.org.in/rdocs/Speeches/PDFs...
# 7919   https://rbidocs.rbi.org.in/rdocs/Speeches/PDFs...
# 7920   https://rbidocs.rbi.org.in/rdocs/Speeches/PDFs...
# 7921   https://rbidocs.rbi.org.in/rdocs/Speeches/PDFs...
# ...                                                  ...
# 28531            https://www.bis.org/review/r981221b.pdf
# 28549            https://www.bis.org/review/r990205b.pdf
# 28560            https://www.bis.org/review/r990215c.pdf
# 28631            https://www.bis.org/review/r990531b.pdf
# 28638            https://www.bis.org/review/r990615b.pdf
#
#                                                    Title  \
# 7917   Indias Economic Reforms: Reflections on the Un...
# 7918                             Future of Rural Banking
# 7919   Finance and Development  Which Way Now? - Bima...
# 7920                 "Is Inflation Dead" - Some Comments
# 7921                 Agenda for Banking in the Millenium
# ...                                                  ...
# 28531  Mr Jalan looks towards a more vibrant banking ...
# 28549  Mr Talwar considers emerging trends in supervi...
# 28560  Mr Reddy discusses issues in fixed income mark...
# 28631  Mr Reddy discusses monetary policy in India  (...
# 28638  Mr Reddy looks at external debt policies in em...
#
#                                                 Subtitle        Date  \
# 7917   Indias Economic Reforms: Reflections on the Un...  2017-12-11
# 7918                             Future of Rural Banking  1999-12-04
# 7919             Finance and Development  Which Way Now?  1999-12-06
# 7920                 "Is Inflation Dead" - Some Comments  2000-02-02
# 7921                 Agenda for Banking in the Millenium  2000-02-09
# ...                                                  ...         ...
# 28531  Inaugural address by the Governor of the Reser...  1998-12-16
# 28549  Speech by Mr S P Talwar, a Deputy Governor of ...  1999-01-27
# 28560  Inaugural address by Dr Y V Reddy, a Deputy Go...  1999-11-02
# 28631  Speech by Y.V. Reddy, Deputy Governor of the R...  1999-05-26
# 28638  Speech by the Deputy Governor of the Reserve B...  1999-06-11
#
#                  Authorname             Role Gender            CentralBank  \
# 7917            Vijay Joshi  Deputy Governor   Male  Reserve Bank of India
# 7918   Yaga Venugopal Reddy  Deputy Governor   Male  Reserve Bank of India
# 7919            Bimal Jalan         Governor   Male  Reserve Bank of India
# 7920   Yaga Venugopal Reddy  Deputy Governor   Male  Reserve Bank of India
# 7921            Bimal Jalan         Governor   Male  Reserve Bank of India
# ...                     ...              ...    ...                    ...
# 28531           Bimal Jalan         Governor   Male  Reserve Bank of India
# 28549            S P Talwar  Deputy Governor   Male  Reserve Bank of India
# 28560  Yaga Venugopal Reddy         Governor   Male  Reserve Bank of India
# 28631  Yaga Venugopal Reddy         Governor   Male  Reserve Bank of India
# 28638  Yaga Venugopal Reddy         Governor   Male  Reserve Bank of India
#
#       Country                                               text  \
# 7917      IND  Indias Economic Reforms: Reflections on the Un...
# 7918      IND  Future of Rural Banking* Respected Professor K...
# 7919      IND  Finance and Development  Which Way Now? The An...
# 7920      IND  "Is Inflation Dead" - Some Comments* Honourabl...
# 7921      IND  Agenda for Banking in the Millenium* Thank you...
# ...       ...                                                ...
# 28531     IND  Mr Jalan looks towards a more vibrant banking ...
# 28549     IND  Mr Talwar considers emerging trends in supervi...
# 28560     IND  Mr Reddy discusses issues in fixed income mark...
# 28631     IND  Mr Reddy discusses monetary policy in India Sp...
# 28638     IND  Mr Reddy looks at external debt policies in em...
#
#       text_original                                           Filename  \
# 7917            NaN  ind_02sp10021840cf3ece274447f1824d42d94c41a427...
# 7918            NaN                                          ind_10428
# 7919            NaN                                          ind_10445
# 7920            NaN                                          ind_11265
# 7921            NaN                                          ind_11444
# ...             ...                                                ...
# 28531           NaN                                           r981221b
# 28549           NaN                                           r990205b
# 28560           NaN                                           r990215c
# 28631           NaN                                           r990531b
# 28638           NaN                                           r990615b
#
#       Language       Source
# 7917   English  CB websites
# 7918   English  CB websites
# 7919   English  CB websites
# 7920   English  CB websites
# 7921   English  CB websites
# ...        ...          ...
# 28531  English          BIS
# 28549  English          BIS
# 28560  English          BIS
# 28631  English          BIS
# 28638  English          BIS
#
# [1071 rows x 15 columns]

# %%
df_original = pd.read_csv('../Data/Speeches/cleaned_speeches.csv', sep='\t')

# %%
df_original.groupby('speechID')#['nWords'].sum().astype(float).describe()  # 1200 speeches, average 5900 words, median 4400
# Out:
#        speechID                                         speechName  paraNum  \
# 0             1               developments-in-uk-financial-markets        1
# 1             1               developments-in-uk-financial-markets        2
# 2             1               developments-in-uk-financial-markets        3
# 3             1               developments-in-uk-financial-markets        4
# 4             1               developments-in-uk-financial-markets        5
# ...         ...                                                ...      ...
# 88401      1495  cost-of-capital-and-uk-business-investment-sli...       17
# 88402      1503  remarks-given-by-swati-dhingra-at-econdat-2024...       10
# 88403      1520      monetary-policy-lessons-from-the-pandemic.pdf        3
# 88404      1520      monetary-policy-lessons-from-the-pandemic.pdf        5
# 88405      1520      monetary-policy-lessons-from-the-pandemic.pdf        6
#
#                                                     para  nWords  isFootnote  \
# 0      Developments in UK financial markets Speech gi...      43       False
# 1      "The UKs new monetary framework Perhaps the si...     146       False
# 2      The framework put in place with that announcem...      33       False
# 3      "First, the target the Bank of England is to p...      79       False
# 4      "Secondly, it is then the responsibility of th...     120       False
# ...                                                  ...     ...         ...
# 88401  Sales surprises and the marginal propensity to...     149       False
# 88402  Bank of England Page 12 Appendix Chart 8: Cent...      44       False
# 88403  Analytical Toolkit Fools Gold: refinements to ...      19       False
# 88404  Analytical Toolkit Fools Gold: forecast refine...      19       False
# 88405  Research design to understand mechanisms Granu...     126       False
#
#        isGraphic  isEndMatter        date           speaker  isMPC  isFPC  \
# 0          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 1          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 2          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 3          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# 4          False        False  1997-11-18  IAN PLENDERLEITH   True  False
# ...          ...          ...         ...               ...    ...    ...
# 88401      False        False  2024-05-17  CATHERINE L MANN   True  False
# 88402      False        False  2024-05-10     SWATI DHINGRA   True  False
# 88403      False        False  2024-10-14     SWATI DHINGRA   True  False
# 88404      False        False  2024-10-14     SWATI DHINGRA   True  False
# 88405      False        False  2024-10-14     SWATI DHINGRA   True  False
#
#        isPRC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 88401  False
# 88402  False
# 88403  False
# 88404  False
# 88405  False
#
# [88406 rows x 13 columns]
